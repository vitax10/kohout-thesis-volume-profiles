# %%
# %pip install vectorbt
# libta-lib
#url = 'https://anaconda.org/conda-forge/libta-lib/0.4.0/download/linux-64/libta-lib-0.4.0-h166bdaf_1.tar.bz2'
#!curl -L $url | tar xj -C /usr/lib/x86_64-linux-gnu/ lib --strip-components=1

# ta-lib Python package for Python 3.10
#!wget https://anaconda.org/conda-forge/ta-lib/0.4.19/download/linux-64/ta-lib-0.4.19-py310hde88566_4.tar.bz2

# Extracting the package
#!tar -xjf ta-lib-0.4.19-py310hde88566_4.tar.bz2

# Moving talib to site-packages
#!mv ./lib/python3.10/site-packages/talib /usr/local/lib/python3.10/dist-packages/

# %%
from dask.distributed import Client, LocalCluster
import json
import logging
import os
import glob
from datetime import timedelta
import pandas as pd
import numpy as np
import pyarrow as pa
import pyarrow.parquet as pq
import dask.dataframe as dd
import dask
import vectorbt as vbt
import matplotlib.pyplot as plt
import talib
from dask.diagnostics import ProgressBar

# %% [markdown]
# ### Configurations

# %%
# Setting up progress bar for Dask operations
ProgressBar().register()

# Configuring Dask spill-to-disk
temp_dir = "/tmp/dask-spill"  
os.makedirs(temp_dir, exist_ok=True)

# Seingt up LocalCluster with 8 workers for better parallelism
cluster = LocalCluster(
    n_workers=8,                     # More workers for 8 vCPUs
    threads_per_worker=2,            # 2 threads per worker
    memory_limit="6GB",              # ~48GB total
    processes=True,                  
    local_directory=temp_dir         
)
client = Client(cluster)
print("Dask Dashboard:", client.dashboard_link)

dask.config.set({
    "temporary-directory": temp_dir,
    "distributed.worker.memory.spill": 0.7,    
    "distributed.worker.memory.target": 0.6,   
    "distributed.worker.memory.pause": 0.85,   
    "distributed.worker.memory.terminate": 0.95,  
})
# Out:
# INFO:distributed.scheduler:State start
# INFO:distributed.scheduler:  Scheduler at:     tcp://127.0.0.1:44787
# INFO:distributed.scheduler:  dashboard at:  http://127.0.0.1:8787/status
# INFO:distributed.scheduler:Registering Worker plugin shuffle
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:43113'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:34003'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:33495'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:37811'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:38131'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:37249'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:40893'
# INFO:distributed.nanny:        Start Nanny at: 'tcp://127.0.0.1:33195'
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:40481 name: 2
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:40481
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:37268
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:42915 name: 4
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:42915
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:37272
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:38027 name: 5
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:38027
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:37284
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:37267 name: 0
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:37267
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:37300
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:36305 name: 3
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:36305
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:37308
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:36593 name: 6
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:36593
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:37318
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:33903 name: 1
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:33903
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:37324
# INFO:distributed.scheduler:Register worker addr: tcp://127.0.0.1:40363 name: 7
# INFO:distributed.scheduler:Starting worker compute stream, tcp://127.0.0.1:40363
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:37330
# INFO:distributed.scheduler:Receive client connection: Client-cf037c13-291d-11f0-b9c2-0242c0a80a0a
# INFO:distributed.core:Starting established connection to tcp://127.0.0.1:37344
# Dask Dashboard: http://127.0.0.1:8787/status

# %%
# Logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Directory and file constants
BASE_DIR = "/content/backtesting_final"
TICKER_JSON = "nasdaq100_ticker_dataset.json"
LOG_CSV = "regime_counts.csv"
PLOT_DIR = "plots"
OUTPUT_DIR = "output"
REGIMES_DIR = os.path.join(BASE_DIR, "_regimes")

# Loading NASDAQ-100 tickers
print(f"Loading tickers from {TICKER_JSON}")
try:
    with open(TICKER_JSON, 'r') as f:
        ticker_data = json.load(f)
    tickers = sorted(set(item['Ticker'] for item in ticker_data))
except Exception as e:
    logging.error(f"Failed to load tickers from {TICKER_JSON}: {str(e)}")
    raise

# Loading earliest dates for each ticker
earliest_dates_df = pd.read_csv('earliest_dates.csv')

# Schemas
input_schema = pa.schema([
    ('ticker', pa.string()),
    ('timestamp', pa.timestamp('ns')),
    ('open', pa.float64()),
    ('high', pa.float64()),
    ('low', pa.float64()),
    ('close', pa.float64()),
    ('volume', pa.float32()),
    ('prev_session_high', pa.float32()),
    ('prev_session_low', pa.float32()),
    ('estimated_bid_ask_spread', pa.float32()),
    ('estimated_obd', pa.float32()),
    ('50_day_sma', pa.float32()),
    ('news_impact', pa.int8())
])
for field in input_schema:
    print(f"  {field.name}: {field.type}")

output_schema = pa.schema([
    ('ticker', pa.string()),
    ('date', pa.timestamp('ns')),
    ('volatility_regime', pa.string()),
    ('trend_regime', pa.string()),
    ('liquidity_regime', pa.string()),
    ('news_impact', pa.int8())
])
for field in output_schema:
    print(f"  {field.name}: {field.type}")

# %% [markdown]
# ### Preprocessing files based on schema

# %%
def preprocess_parquet_file(input_file, output_file):
    try:
        table = pq.read_table(input_file, schema=input_schema)
        df = table.to_pandas()
        df = df.drop_duplicates(subset=['timestamp'], keep='last')
        # Validating price consistency
        invalid_prices = df[(df['high'] < df['low']) |
                          (df['close'] > df['high']) |
                          (df['close'] < df['low'])]
        if not invalid_prices.empty:
            logging.warning(f"Invalid prices detected in {input_file}: {len(invalid_prices)} rows")
            df = df[~((df['high'] < df['low']) |
                      (df['close'] > df['high']) |
                      (df['close'] < df['low']))]
        table = pa.Table.from_pandas(df, schema=input_schema)
        os.makedirs(os.path.dirname(output_file), exist_ok=True)
        with pq.ParquetWriter(output_file, input_schema, compression='snappy', use_dictionary=False) as writer:
            writer.write_table(table)
        print(f"Preprocessed {input_file} to {output_file}")
        return True
    except Exception as e:
        logging.error(f"Error preprocessing {input_file}: {str(e)}")
        return False

def preprocess_ticker_files(ticker):
    ticker_path = os.path.join(BASE_DIR, f'ticker={ticker}')
    output_path = os.path.join(BASE_DIR, f'ticker={ticker}_preprocessed')
    parquet_files = glob.glob(os.path.join(ticker_path, '*.parquet'))
    preprocessed_files = []
    for file in parquet_files:
        output_file = os.path.join(output_path, os.path.basename(file))
        if preprocess_parquet_file(file, output_file):
            preprocessed_files.append(output_file)
    return preprocessed_files, parquet_files

# %% [markdown]
# ### Regime classification functions

# %%
def compute_volatility_regime(stoch_k, k_low, k_high):
    if pd.isna(stoch_k) or pd.isna(k_low) or pd.isna(k_high):
        logging.info(f"Volatility regime undefined: stoch_k={stoch_k}, k_low={k_low}, k_high={k_high}")
        return 'undefined'
    if stoch_k < k_low:
        logging.info(f"Low volatility assigned: stoch_k={stoch_k} < k_low={k_low}")
        return 'Low'
    elif stoch_k > k_high:
        logging.info(f"High volatility assigned: stoch_k={stoch_k} > k_high={k_high}")
        return 'High'
    logging.info(f"Medium volatility assigned: {k_low} <= stoch_k={stoch_k} <= k_high={k_high}")
    return 'Medium'

def compute_trend_regime(adx, plus_di, minus_di, high, low, bb_width, adx_low, adx_high, bb_width_low):
    if pd.isna(adx) or pd.isna(plus_di) or pd.isna(minus_di) or pd.isna(bb_width) or pd.isna(adx_low) or pd.isna(adx_high):
        logging.info(f"Trend regime undefined: adx={adx}, plus_di={plus_di}, minus_di={minus_di}, bb_width={bb_width}, adx_low={adx_low}, adx_high={adx_high}")
        return 'undefined'
    if bb_width == 0:
        logging.info("Trend regime undefined: bb_width is zero")
        return 'undefined'
    higher_highs = high[-1] > high[-2] if len(high) > 1 else False
    higher_lows = low[-1] > low[-2] if len(low) > 1 else False
    lower_highs = high[-1] < high[-2] if len(high) > 1 else False
    lower_lows = low[-1] < low[-2] if len(low) > 1 else False
    if adx > adx_high and plus_di > minus_di and (higher_highs or higher_lows):
        logging.info(f"Uptrend assigned: adx={adx} > adx_high={adx_high}, plus_di={plus_di} > minus_di={minus_di}, higher_highs={higher_highs}, higher_lows={higher_lows}")
        return 'Uptrend'
    elif adx > adx_high and minus_di > plus_di and (lower_highs or lower_lows):
        logging.info(f"Downtrend assigned: adx={adx} > adx_high={adx_high}, minus_di={minus_di} > plus_di={plus_di}, lower_highs={lower_highs}, lower_lows={lower_lows}")
        return 'Downtrend'
    elif adx < adx_low and (pd.isna(bb_width_low) or bb_width < bb_width_low):
        logging.info(f"Range assigned: adx={adx} < adx_low={adx_low}, bb_width={bb_width} < bb_width_low={bb_width_low}")
        return 'Range'
    logging.info(f"Range assigned: no strong trend conditions met")
    return 'Range'

def compute_liquidity_regime(spread, obd, volume, spread_low, spread_high, obd_low, obd_high, volume_high):
    if pd.isna(spread) or pd.isna(obd) or pd.isna(spread_low) or pd.isna(spread_high) or pd.isna(obd_low) or pd.isna(obd_high):
        if not pd.isna(volume) and volume > volume_high:
            logging.info(f"High liquidity assigned based on high volume: volume={volume} > volume_high={volume_high}")
            return 'High'
        logging.info("Using 'Medium' liquidity regime due to missing spread/obd data")
        return 'Medium'
    spread_pct = spread / 100
    logging.info(f"Liquidity check: spread_pct={spread_pct}, spread_low={spread_low}, spread_high={spread_high}, obd={obd}, obd_low={obd_low}, obd_high={obd_high}, volume={volume}, volume_high={volume_high}")
    if spread_pct < spread_low and (obd > obd_high or volume > volume_high):
        logging.info("High liquidity assigned: tight spread and high obd or volume")
        return 'High'
    elif spread_pct > spread_high and obd < obd_low:
        logging.info("Low liquidity assigned: wide spread and low obd")
        return 'Low'
    logging.info("Liquidity regime set to 'Medium' as conditions for 'High' or 'Low' not met")
    return 'Medium'

# %% [markdown]
# ### Ticker processing and computing metrics functions, assigning regimes

# %%
def process_ticker_day(ticker, date, df, lookback=30, quantile_window=252):
    print(f"\nProcessing ticker {ticker} for date {date}")
    try:
        date = pd.Timestamp(date)
        end_date = date - timedelta(days=1)  # Last day of historical data
        quantile_start = date - timedelta(days=quantile_window)

        # Filtering minute-level data up to end_date (excluding date)
        window = df[(df['timestamp'].dt.date <= end_date.date())]
        trading_days = sorted(window['timestamp'].dt.date.unique().compute())

        # Dynamically setting lookback period: min 27, max 30
        min_lookback = 27
        if len(trading_days) < min_lookback:
            logging.warning(f"Insufficient trading days ({len(trading_days)}) for {ticker} on {date.date()}")
            print(f"Insufficient trading days: {len(trading_days)}")
            return pd.DataFrame([{
                'ticker': ticker,
                'date': date,
                'volatility_regime': 'undefined',
                'trend_regime': 'undefined',
                'liquidity_regime': 'undefined',
                'news_impact': 0
            }])
        effective_lookback = min(max(min_lookback, len(trading_days)), lookback)
        start_date = trading_days[-effective_lookback]

        # Filtering window for lookback period
        window = df[(df['timestamp'].dt.date >= start_date) & (df['timestamp'].dt.date <= end_date.date())]
        quantile_window_data = df[(df['timestamp'].dt.date >= quantile_start.date()) & (df['timestamp'].dt.date <= end_date.date())]

        window_days = window['timestamp'].dt.date.nunique().compute()
        window_pd = window.compute()

        if window_pd.empty or window_days < min_lookback:
            logging.warning(f"Insufficient data in lookback window for ticker {ticker} on {date.date()} (days: {window_days}).")
            return pd.DataFrame([{
                'ticker': ticker,
                'date': date,
                'volatility_regime': 'undefined',
                'trend_regime': 'undefined',
                'liquidity_regime': 'undefined',
                'news_impact': 0
            }])

        # Aggregating to daily data
        window_pd['date'] = window_pd['timestamp'].dt.floor('D')
        daily_pd = window_pd.groupby(['ticker', 'date']).agg({
            'open': 'first',
            'high': 'max',
            'low': 'min',
            'close': 'last',
            'volume': 'sum',
            'estimated_bid_ask_spread': 'mean',
            'estimated_obd': 'mean',
            'news_impact': 'max'  # 1 if any minute has news, else 0
        }).reset_index()

        # Ensuring sufficient daily data
        if len(daily_pd) < min_lookback:
            logging.warning(f"Insufficient daily data ({len(daily_pd)} days) for {ticker} on {date.date()}")
            return pd.DataFrame([{
                'ticker': ticker,
                'date': date,
                'volatility_regime': 'undefined',
                'trend_regime': 'undefined',
                'liquidity_regime': 'undefined',
                'news_impact': 0
            }])

        # Clipping estimated_obd
        daily_pd['estimated_obd'] = daily_pd['estimated_obd'].clip(lower=1000.0)

        # Validating and clean daily data
        for col in ['high', 'low', 'close']:
            if daily_pd[col].isna().any():
                daily_pd[col] = daily_pd[col].fillna(method='ffill', limit=5).fillna(method='bfill', limit=5)
            print(f"Daily {col} dtype: {daily_pd[col].dtype}, NaNs: {daily_pd[col].isna().sum()}")

        # Checking price consistency
        invalid_prices = daily_pd[(daily_pd['high'] < daily_pd['low']) |
                                (daily_pd['close'] > daily_pd['high']) |
                                (daily_pd['close'] < daily_pd['low'])]
        if not invalid_prices.empty:
            logging.warning(f"Invalid prices detected for {ticker} on {date.date()}: {len(invalid_prices)} rows")
            return pd.DataFrame([{
                'ticker': ticker,
                'date': date,
                'volatility_regime': 'undefined',
                'trend_regime': 'undefined',
                'liquidity_regime': 'undefined',
                'news_impact': 0
            }])

        if daily_pd[['high', 'low', 'close']].isna().any().any():
            logging.warning(f"Daily data for {ticker} on {date.date()} contains NaNs after cleaning.")
            return pd.DataFrame([{
                'ticker': ticker,
                'date': date,
                'volatility_regime': 'undefined',
                'trend_regime': 'undefined',
                'liquidity_regime': 'undefined',
                'news_impact': 0
            }])

        # Checking for zero standard deviation
        close_std = daily_pd['close'].std()
        if close_std == 0 or pd.isna(close_std):
            logging.warning(f"Zero or NaN standard deviation in daily close prices for {ticker} on {date.date()}")
            return pd.DataFrame([{
                'ticker': ticker,
                'date': date,
                'volatility_regime': 'undefined',
                'trend_regime': 'undefined',
                'liquidity_regime': 'undefined',
                'news_impact': 0
            }])

        # Computing Stochastic Oscillator %K on daily data
        try:
            stoch = vbt.IndicatorFactory.from_talib('STOCH').run(
                high=daily_pd['high'],
                low=daily_pd['low'],
                close=daily_pd['close'],
                fastk_period=14
            )
            stoch_k = stoch.slowk.iloc[-1] if not stoch.slowk.empty else np.nan
        except Exception as e:
            logging.error(f"Error computing STOCH for {ticker} on {date.date()}: {str(e)}")
            stoch_k = np.nan

        # Computing ADX on daily data
        try:
            adx = vbt.IndicatorFactory.from_talib('ADX').run(
                high=daily_pd['high'],
                low=daily_pd['low'],
                close=daily_pd['close'],
                timeperiod=14
            )
            adx_val = adx.real.iloc[-1] if not adx.real.empty else np.nan
        except Exception as e:
            logging.error(f"Error computing ADX for {ticker} on {date.date()}: {str(e)}")
            adx_val = np.nan

        # Computing PLUS_DI on daily data
        try:
            plus_di = vbt.IndicatorFactory.from_talib('PLUS_DI').run(
                high=daily_pd['high'],
                low=daily_pd['low'],
                close=daily_pd['close'],
                timeperiod=14
            )
            plus_di_val = plus_di.real.iloc[-1] if not plus_di.real.empty else np.nan
        except Exception as e:
            logging.error(f"Error computing PLUS_DI for {ticker} on {date.date()}: {str(e)}")
            plus_di_val = np.nan

        # Computing MINUS_DI on daily data
        try:
            minus_di = vbt.IndicatorFactory.from_talib('MINUS_DI').run(
                high=daily_pd['high'],
                low=daily_pd['low'],
                close=daily_pd['close'],
                timeperiod=14
            )
            minus_di_val = minus_di.real.iloc[-1] if not minus_di.real.empty else np.nan
        except Exception as e:
            logging.error(f"Error computing MINUS_DI for {ticker} on {date.date()}: {str(e)}")
            minus_di_val = np.nan

        # Computing Bollinger Bands on daily data
        try:
            bbands = vbt.IndicatorFactory.from_talib('BBANDS').run(
                close=daily_pd['close'],
                timeperiod=14
            )
            bb_width = (bbands.upperband - bbands.lowerband) / bbands.middleband
            bb_width_val = bb_width.iloc[-1] if not bb_width.empty else np.nan
        except Exception as e:
            logging.error(f"Error computing BBANDS for {ticker} on {date.date()}: {str(e)}")
            bb_width_val = np.nan

        # Extracting liquidity metrics and news impact from the last available trading day
        last_day = daily_pd[daily_pd['date'] == end_date]
        if last_day.empty:
            last_day = daily_pd[daily_pd['date'] <= end_date].tail(1)
        spread = last_day['estimated_bid_ask_spread'].iloc[-1] if not last_day.empty else np.nan
        obd = last_day['estimated_obd'].iloc[-1] if not last_day.empty else np.nan
        volume = last_day['volume'].iloc[-1] if not last_day.empty else np.nan
        news_impact = int(last_day['news_impact'].iloc[-1]) if not last_day.empty and not pd.isna(last_day['news_impact'].iloc[-1]) else 0

        # Computing thresholds using quantile window
        if len(quantile_window_data) >= quantile_window // 2:
            quantile_pd = quantile_window_data.compute()

            # Aggregating quantile data to daily
            quantile_pd['date'] = quantile_pd['timestamp'].dt.floor('D')
            daily_quantile_pd = quantile_pd.groupby(['ticker', 'date']).agg({
                'open': 'first',
                'high': 'max',
                'low': 'min',
                'close': 'last',
                'volume': 'sum',
                'estimated_bid_ask_spread': 'mean',
                'estimated_obd': 'mean',
                'news_impact': 'max'
            }).reset_index()

            if daily_quantile_pd.empty:
                logging.info(f"Empty quantile window for ticker {ticker} on {date.date()}.")
                k_low, k_high = 20, 80
                adx_low, adx_high = 20, 25
                bb_width_low = np.nan
                spread_low, spread_high = 0.00002, 0.0001
                obd_low, obd_high = 10000.0, 50000.0
                volume_high = 1e7
            else:
                # Validating and cleaning quantile window data
                for col in ['high', 'low', 'close']:
                    if daily_quantile_pd[col].isna().any():
                        daily_quantile_pd[col] = daily_quantile_pd[col].fillna(method='ffill', limit=5).fillna(method='bfill', limit=5)

                if daily_quantile_pd[['high', 'low', 'close']].isna().any().any():
                    logging.warning(f"Daily quantile data for {ticker} on {date.date()} contains NaNs after cleaning.")
                    k_low, k_high = 20, 80
                    adx_low, adx_high = 20, 25
                    bb_width_low = np.nan
                    spread_low, spread_high = 0.00002, 0.0001
                    obd_low, obd_high = 10000.0, 50000.0
                    volume_high = 1e7
                else:
                    # Stochastic %K thresholds
                    try:
                        stoch_full = vbt.IndicatorFactory.from_talib('STOCH').run(
                            high=daily_quantile_pd['high'],
                            low=daily_quantile_pd['low'],
                            close=daily_quantile_pd['close'],
                            fastk_period=14
                        )
                        k_low = stoch_full.slowk.quantile(0.15) if not stoch_full.slowk.empty else 20
                        k_high = stoch_full.slowk.quantile(0.75) if not stoch_full.slowk.empty else 80
                    except Exception as e:
                        logging.error(f"Error computing STOCH (quantile) for {ticker} on {date.date()}: {str(e)}")
                        k_low, k_high = 20, 80

                    # ADX thresholds
                    try:
                        adx_full = vbt.IndicatorFactory.from_talib('ADX').run(
                            high=daily_quantile_pd['high'],
                            low=daily_quantile_pd['low'],
                            close=daily_quantile_pd['close'],
                            timeperiod=14
                        )
                        adx_low = adx_full.real.quantile(0.25) if not adx_full.real.empty else 20
                        adx_high = adx_full.real.quantile(0.75) if not adx_full.real.empty else 25
                    except Exception as e:
                        logging.error(f"Error computing ADX (quantile) for {ticker} on {date.date()}: {str(e)}")
                        adx_low, adx_high = 20, 25

                    # Bollinger Band Width threshold
                    try:
                        bbands_full = vbt.IndicatorFactory.from_talib('BBANDS').run(
                            close=daily_quantile_pd['close'],
                            timeperiod=14
                        )
                        bb_width_full = (bbands_full.upperband - bbands_full.lowerband) / bbands.middleband
                        bb_width_low = bb_width_full.quantile(0.05) if not bb_width_full.empty else np.nan
                    except Exception as e:
                        logging.error(f"Error computing BBANDS (quantile) for {ticker} on {date.date()}: {str(e)}")
                        bb_width_low = np.nan

                    # Liquidity thresholds
                    daily_quantile_pd['estimated_obd'] = daily_quantile_pd['estimated_obd'].clip(lower=1000.0)
                    spread_low = daily_quantile_pd['estimated_bid_ask_spread'].quantile(0.1) / 100 if not daily_quantile_pd.empty else 0.00002
                    spread_high = daily_quantile_pd['estimated_bid_ask_spread'].quantile(0.95) / 100 if not daily_quantile_pd.empty else 0.0001
                    obd_low = daily_quantile_pd['estimated_obd'].quantile(0.3) if not daily_quantile_pd.empty else 10000.0
                    obd_high = daily_quantile_pd['estimated_obd'].quantile(0.7) if not daily_quantile_pd.empty else 50000.0
                    volume_high = daily_quantile_pd['volume'].quantile(0.7) if not daily_quantile_pd.empty else 1e7
        else:
            logging.info(f"Using static thresholds for {ticker} on {date.date()} due to insufficient quantile data ({len(quantile_window_data)} days).")
            k_low, k_high = 20, 80
            adx_low, adx_high = 20, 25
            bb_width_low = np.nan
            spread_low, spread_high = 0.00002, 0.0001
            obd_low, obd_high = 10000.0, 50000.0
            volume_high = 1e7

        # Assigning regimes
        volatility_regime = compute_volatility_regime(stoch_k, k_low, k_high)
        trend_regime = compute_trend_regime(
            adx_val, plus_di_val, minus_di_val,
            daily_pd['high'].values[-2:], daily_pd['low'].values[-2:],
            bb_width_val, adx_low, adx_high, bb_width_low
        )
        liquidity_regime = compute_liquidity_regime(
            spread, obd, volume, spread_low, spread_high, obd_low, obd_high, volume_high
        )
        logging.info(f"Regimes assigned for {date.date()}: Volatility={volatility_regime}, Trend={trend_regime}, Liquidity={liquidity_regime}, News Impact={news_impact}")

        regime = {
            'ticker': ticker,
            'date': date,
            'volatility_regime': volatility_regime,
            'trend_regime': trend_regime,
            'liquidity_regime': liquidity_regime,
            'news_impact': news_impact
        }

        regime_df = pd.DataFrame([regime])
        return regime_df
    
    except Exception as e:
        logging.error(f"Error processing ticker {ticker} on {date.date()}: {str(e)}")
        return pd.DataFrame([{
            'ticker': ticker,
            'date': date,
            'volatility_regime': 'undefined',
            'trend_regime': 'undefined',
            'liquidity_regime': 'undefined',
            'news_impact': 0
        }])

def process_ticker(ticker, lookback=30, quantile_window=252):
    logging.info(f"\nStarting process_ticker for {ticker}")
    try:
        preprocessed_files, original_files = preprocess_ticker_files(ticker)
        files_to_process = preprocessed_files if preprocessed_files else original_files
        if not files_to_process:
            logging.warning(f"No Parquet files for {ticker}")
            return None

        dask.config.set({'dataframe.shuffle.compression': None})
        dask.config.set({'parquet.metadata': None})
        dask.config.set({'scheduler': 'threads'})

        df = dd.read_parquet(
            files_to_process,
            schema=input_schema,
            columns=[
                'ticker', 'timestamp', 'open', 'high', 'low', 'close', 'volume',
                'estimated_bid_ask_spread', 'estimated_obd', 'news_impact'
            ],
            engine='pyarrow',
            dtype_backend='pyarrow'
        )
        df['ticker'] = df['ticker'].astype('string[pyarrow]')
        df['timestamp'] = df['timestamp'].astype('timestamp[ns][pyarrow]')

        # Earliest_date based on ticker
        earliest_dates = {
            row['Ticker']: pd.Timestamp(row['Earliest_Date'])
            for _, row in earliest_dates_df.iterrows()
        }
        earliest_date = earliest_dates.get(ticker, pd.Timestamp('2020-05-04'))
        logging.info(f"Earliest date for {ticker}: {earliest_date}")

        trading_days = sorted(df['timestamp'].dt.date.unique().compute())
        trading_days = [pd.Timestamp(d) for d in trading_days if pd.Timestamp(d) >= earliest_date + timedelta(days=lookback)]

        regimes = [process_ticker_day(ticker, date, df, lookback, quantile_window) for date in trading_days]
        if not regimes:
            logging.warning(f"No regimes computed for {ticker}")
            return None

        regimes_df = pd.concat(regimes, ignore_index=True)
        regimes_df['ticker'] = regimes_df['ticker'].astype(str)
        regimes_df['date'] = regimes_df['date'].astype('datetime64[ns]')
        regimes_df['news_impact'] = regimes_df['news_impact'].astype('int8')

        # Saving daily regimes to CSV
        output_path = os.path.join(REGIMES_DIR, f'ticker={ticker}', 'daily_regimes.csv')
        os.makedirs(os.path.dirname(output_path), exist_ok=True)
        regimes_df.to_csv(output_path, index=False)
        return regimes_df
    
    except Exception as e:
        logging.error(f"Error processing {ticker}: {str(e)}")
        return None
# Out:
# Loading tickers from nasdaq100_ticker_dataset.json
# Input schema defined:
#   ticker: string
#   timestamp: timestamp[ns]
#   open: double
#   high: double
#   low: double
#   close: double
#   volume: float
#   prev_session_high: float
#   prev_session_low: float
#   estimated_bid_ask_spread: float
#   estimated_obd: float
#   50_day_sma: float
#   news_impact: int8
# Output schema defined:
#   ticker: string
#   date: timestamp[ns]
#   volatility_regime: string
#   trend_regime: string
#   liquidity_regime: string
#   news_impact: int8
# Starting script execution
#
# Starting main function
#
# Processing ticker: AAPL
#
# Starting process_ticker for AAPL
# Preprocessed /content/backtesting_final/ticker=AAPL/part.7.parquet to /content/backtesting_final/ticker=AAPL_preprocessed/part.7.parquet
# Preprocessed /content/backtesting_final/ticker=AAPL/part.8.parquet to /content/backtesting_final/ticker=AAPL_preprocessed/part.8.parquet
# Preprocessed /content/backtesting_final/ticker=AAPL/part.1.parquet to /content/backtesting_final/ticker=AAPL_preprocessed/part.1.parquet
# Preprocessed /content/backtesting_final/ticker=AAPL/part.2.parquet to /content/backtesting_final/ticker=AAPL_preprocessed/part.2.parquet
# Preprocessed /content/backtesting_final/ticker=AAPL/part.9.parquet to /content/backtesting_final/ticker=AAPL_preprocessed/part.9.parquet
# Preprocessed /content/backtesting_final/ticker=AAPL/part.4.parquet to /content/backtesting_final/ticker=AAPL_preprocessed/part.4.parquet
# Preprocessed /content/backtesting_final/ticker=AAPL/part.0.parquet to /content/backtesting_final/ticker=AAPL_preprocessed/part.0.parquet
# Preprocessed /content/backtesting_final/ticker=AAPL/part.6.parquet to /content/backtesting_final/ticker=AAPL_preprocessed/part.6.parquet
# Preprocessed /content/backtesting_final/ticker=AAPL/part.3.parquet to /content/backtesting_final/ticker=AAPL_preprocessed/part.3.parquet
# Preprocessed /content/backtesting_final/ticker=AAPL/part.5.parquet to /content/backtesting_final/ticker=AAPL_preprocessed/part.5.parquet
# WARNING:root:Insufficient trading days (21) for AAPL on 2020-06-03
# WARNING:root:Insufficient trading days (22) for AAPL on 2020-06-04
# Processing ticker AAPL for date 2020-06-03 00:00:00
# Predicting regime for 2020-06-03 using lookback from 2020-06-02 to earlier
# Quantile window for thresholds: 2019-09-25 to 2020-06-02
# Total trading days available up to 2020-06-02: 21
# Insufficient trading days: 21
#
# Processing ticker AAPL for date 2020-06-04 00:00:00
# Predicting regime for 2020-06-04 using lookback from 2020-06-03 to earlier
# Quantile window for thresholds: 2019-09-26 to 2020-06-03
# Total trading days available up to 2020-06-03: 22
# Insufficient trading days: 22
#
# Processing ticker AAPL for date 2020-06-05 00:00:00
# Predicting regime for 2020-06-05 using lookback from 2020-06-04 to earlier
# Quantile window for thresholds: 2019-09-27 to 2020-06-04
# WARNING:root:Insufficient trading days (23) for AAPL on 2020-06-05
# WARNING:root:Insufficient trading days (24) for AAPL on 2020-06-08
# WARNING:root:Insufficient trading days (25) for AAPL on 2020-06-09
# WARNING:root:Insufficient trading days (26) for AAPL on 2020-06-10
# Výstupní stream byl oříznut na posledních 5000 řádků.
# Parameters: timeperiod=14
# ADX output shape: (30,)
# ADX last value: 42.49271869842114
# ADX sample (last 5): [        nan         nan 46.53162337 43.70051347 42.4927187 ]
# Number of NaNs in ADX: 27
#
# Computing PLUS_DI (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# PLUS_DI output shape: (30,)
# PLUS_DI last value: 17.793323351548963
# PLUS_DI sample (last 5): [21.3543372  24.22628609 22.58548136 21.23493432 17.79332335]
# Number of NaNs in PLUS_DI: 14
#
# Computing MINUS_DI (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# MINUS_DI output shape: (30,)
# MINUS_DI last value: 30.816594357588222
# MINUS_DI sample (last 5): [23.77029778 22.19348882 23.67361892 24.38062173 30.81659436]
# Number of NaNs in MINUS_DI: 14
#
# Computing Bollinger Bands (Daily)
# Daily input shape: close=(30,)
# Parameters: timeperiod=14
# Bollinger Bands output shapes: upperband=(30,), middleband=(30,), lowerband=(30,)
# Bollinger Band Width last value: 0.10690961821882515
# Bollinger Band Width sample (last 5): [0.07405166 0.07779316 0.08673385 0.09203957 0.10690962]
# Number of NaNs in Bollinger Band Width: 13
# Upper Band last value: 262.5502871512337
# Middle Band last value: 249.2278594970703
# Lower Band last value: 235.90543184290692
#
# Extracting liquidity metrics and news impact
# No data for 2025-01-12, using last available day: 2025-01-10 00:00:00
# Last trading day: 2025-01-12, Spread: 0.1829075664281845, OBD: 2116576.0, Volume: 44792468.0, News Impact: 1
#
# Quantile window length: 130963
# Quantile window computed, shape: (130963, 10)
# Quantile window sample:
#       ticker            timestamp        open        high         low  \
# 34240   AAPL  2024-05-06 08:00:00  180.399994  181.630005  180.300003
# 34241   AAPL  2024-05-06 08:01:00  180.970001  181.199997  180.949997
# 34242   AAPL  2024-05-06 08:02:00  181.139999  181.369995  181.139999
# 34243   AAPL  2024-05-06 08:03:00  181.240005  181.320007  181.179993
# 34244   AAPL  2024-05-06 08:04:00  181.259995  181.360001  181.240005
#
#             close   volume  estimated_bid_ask_spread  estimated_obd  \
# 34240  180.970001  36906.0                  1.330002   27748.833984
# 34241  181.199997  23707.0                      0.25        94828.0
# 34242  181.300003   6427.0                  0.229996   27943.998047
# 34243  181.300003   9165.0                  0.140015     65457.4375
# 34244  181.360001   7369.0                  0.119995   61410.832031
#
#        news_impact
# 34240            0
# 34241            0
# 34242            0
# 34243            0
# 34244            0
# Quantile window ticker type: <class 'str'>
# Daily aggregated quantile window shape: (172, 10)
# Daily aggregated quantile window sample:
#   ticker                 date        open        high         low       close  \
# 0   AAPL  2024-05-06 00:00:00  180.399994  184.199997  180.300003  181.820007
# 1   AAPL  2024-05-07 00:00:00  183.020004  184.899994  181.320007  182.394806
# 2   AAPL  2024-05-08 00:00:00  182.300003      183.75  181.449997  182.411407
# 3   AAPL  2024-05-09 00:00:00      182.75  184.779999  182.110001  184.660004
# 4   AAPL  2024-05-10 00:00:00  184.570007  185.089996  182.130005  182.580002
#
#        volume  estimated_bid_ask_spread  estimated_obd  news_impact
# 0  68964752.0                  0.126048    1785374.375            0
# 1  68910928.0                  0.096137     29022674.0            1
# 2  37624484.0                  0.074841      3815606.5            0
# 3  41961968.0                  0.065258     12589430.0            1
# 4  41338480.0                  0.060987      3213500.5            0
#
# Validating and cleaning daily quantile window data
# Daily quantile high dtype: double[pyarrow], NaNs: 0
# Daily quantile low dtype: double[pyarrow], NaNs: 0
# Daily quantile close dtype: double[pyarrow], NaNs: 0
#
# Computing Stochastic %K thresholds (Daily)
# Daily input shapes: high=(172,), low=(172,), close=(172,)
# Parameters: fastk_period=14
# Stochastic %K thresholds: k_low=27.170865181923627, k_high=87.96852247062395
# Stochastic %K (slowk) quantile output shape: (172,)
# Stochastic %K sample (last 5): [17.20998166 12.14395978  9.99046203 11.73076206 10.76616409]
# Number of NaNs in Stochastic %K (quantile): 17
#
# Computing ADX thresholds (Daily)
# Daily input shapes: high=(172,), low=(172,), close=(172,)
# Parameters: timeperiod=14
# ADX thresholds: adx_low=15.959382470397916, adx_high=44.30443661422165
# ADX quantile output shape: (172,)
# ADX sample (last 5): [39.6105001  36.80160788 34.64254871 32.94169634 32.70074583]
# Number of NaNs in ADX (quantile): 27
#
# Computing Bollinger Band Width threshold (Daily)
# Daily input shape: close=(172,)
# Parameters: timeperiod=14
# Bollinger Band Width threshold: 0.028450731310997984
# Bollinger Band Width quantile output shape: (172,)
# Bollinger Band Width sample (last 5): [nan nan nan nan nan]
# Number of NaNs in Bollinger Band Width (quantile): 155
#
# Computing liquidity thresholds (Daily)
# Spread thresholds: low=0.0007817240431904793, high=0.0019245573207736014
# OBD thresholds: low=1839516.625, high=3556875.099999997
# Volume threshold: high=44634611.2
# Sample spread (last 5): <ArrowExtensionArray>
# [0.12725825607776642, 0.11922303587198257, 0.14630374312400818,
#  0.13809674978256226,  0.1829075664281845]
# Length: 5, dtype: float[pyarrow]
# Sample OBD (last 5): <ArrowExtensionArray>
# [1054230.625, 1235713.875, 1328780.5, 1510948.25, 2116576.0]
# Length: 5, dtype: float[pyarrow]
# Sample volume (last 5): <ArrowExtensionArray>
# [31691764.0, 30215420.0, 30383088.0, 26045970.0, 44792468.0]
# Length: 5, dtype: float[pyarrow]
#
# Assigning regimes
# Regimes assigned for 2025-01-13: Volatility=Low, Trend=Range, Liquidity=Medium, News Impact=1
# Regime assigned: {'ticker': 'AAPL', 'date': Timestamp('2025-01-13 00:00:00'), 'volatility_regime': 'Low', 'trend_regime': 'Range', 'liquidity_regime': 'Medium', 'news_impact': 1}
# Regime DataFrame created, shape: (1, 6)
# Regime DataFrame dtypes:
# ticker                       object
# date                 datetime64[ns]
# volatility_regime            object
# trend_regime                 object
# liquidity_regime             object
# news_impact                   int64
# dtype: object
# Regime DataFrame ticker type: <class 'str'>
#
# Processing ticker AAPL for date 2025-01-14 00:00:00
# Predicting regime for 2025-01-14 using lookback from 2025-01-13 to earlier
# Quantile window for thresholds: 2024-05-07 to 2025-01-13
# Total trading days available up to 2025-01-13: 1181
# Lookback window: 2024-11-27 to 2025-01-13, effective lookback: 30 days
# Window shape before compute: (<dask_expr.expr.Scalar: expr=(Filter(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30))), predicate=PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30)))['timestamp'], accessor='dt', attr='date') >= 2024-11-27 & PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30)))['timestamp'], accessor='dt', attr='date') <= 2025-01-13)).size() // 10, dtype=int64>, 10)
# Quantile window shape before compute: (<dask_expr.expr.Scalar: expr=(Filter(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30))), predicate=PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30)))['timestamp'], accessor='dt', attr='date') >= 2024-05-07 & PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30)))['timestamp'], accessor='dt', attr='date') <= 2025-01-13)).size() // 10, dtype=int64>, 10)
# Unique trading days in lookback window: 30
# Lookback window computed, shape: (21234, 10)
# Lookback window sample:
#       ticker            timestamp        open        high         low  \
# 53448   AAPL  2024-11-27 09:00:00       235.5       235.5  234.600006
# 53449   AAPL  2024-11-27 09:01:00  235.089996  235.089996  235.059998
# 53450   AAPL  2024-11-27 09:02:00  235.070007  235.080002  235.059998
# 53451   AAPL  2024-11-27 09:03:00  235.100006  235.210007  235.100006
# 53452   AAPL  2024-11-27 09:04:00  235.100006  235.210007  235.100006
#
#             close   volume  estimated_bid_ask_spread  estimated_obd  \
# 53448  235.089996  10331.0                  0.899994   11478.966797
# 53449  235.059998   1808.0                  0.029999   60269.117188
# 53450  235.059998   2220.0                  0.020004  110976.289062
# 53451  235.160004   2048.0                  0.110001   18618.078125
# 53452  235.160004      0.0                  0.110001            0.0
#
#        news_impact
# 53448            1
# 53449            1
# 53450            1
# 53451            1
# 53452            1
# Lookback window ticker type: <class 'str'>
# Daily aggregated window shape: (30, 10)
# Daily aggregated window sample:
#   ticker                 date        open        high         low       close  \
# 0   AAPL  2024-11-27 00:00:00       235.5  235.720001  233.259995  234.990005
# 1   AAPL  2024-11-29 00:00:00  235.369995  237.809998  233.970001  237.330002
# 2   AAPL  2024-12-02 00:00:00  237.100006  240.789993       236.0  239.600006
# 3   AAPL  2024-12-03 00:00:00       240.0  242.759995  238.899994  242.630005
# 4   AAPL  2024-12-04 00:00:00  242.759995  244.110001      241.25  243.020004
#
#        volume  estimated_bid_ask_spread  estimated_obd  news_impact
# 0  22674984.0                  0.093874     1256570.25            1
# 1  24590042.0                  0.078272    117185912.0            0
# 2  32715624.0                  0.092739     1759777.75            0
# 3  28519624.0                  0.079462      5992564.5            0
# 4  30931738.0                  0.088416     2059837.75            0
#
# Validating and cleaning daily input data
# Daily high dtype: double[pyarrow], NaNs: 0
# Daily low dtype: double[pyarrow], NaNs: 0
# Daily close dtype: double[pyarrow], NaNs: 0
#
# Daily data for indicators:
#                    date        high         low       close      volume  \
# 25  2025-01-06 00:00:00  247.330002  243.199997       245.0  30215420.0
# 26  2025-01-07 00:00:00  245.550003  241.350006  242.190002  30383088.0
# 27  2025-01-08 00:00:00  243.712296  240.050003  242.720001  26045970.0
# 28  2025-01-10 00:00:00       244.0       233.0  236.929993  44792468.0
# 29  2025-01-13 00:00:00  235.979996  229.720001  234.399994  36400696.0
#
#     news_impact
# 25            0
# 26            0
# 27            0
# 28            1
# 29            0
#
# Computing Stochastic Oscillator %K (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: fastk_period=14
# Stochastic %K output shape: (30,)
# Stochastic %K (slowk) last value: 14.407785612405592
# Stochastic %K sample (last 5): [12.14395978  9.99046203 11.73076206 10.76616409 14.40778561]
# Number of NaNs in Stochastic %K: 17
#
# Computing ADX (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# ADX output shape: (30,)
# ADX last value: 39.01805556907504
# ADX sample (last 5): [        nan         nan 40.60025351 39.51547351 39.01805557]
# Number of NaNs in ADX: 27
#
# Computing PLUS_DI (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# PLUS_DI output shape: (30,)
# PLUS_DI last value: 16.39568091157818
# PLUS_DI sample (last 5): [24.82957364 23.15671637 21.77883149 18.26364915 16.39568091]
# Number of NaNs in PLUS_DI: 14
#
# Computing MINUS_DI (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# MINUS_DI output shape: (30,)
# MINUS_DI last value: 32.221295434233305
# MINUS_DI sample (last 5): [22.09605867 23.57500135 24.28438981 30.70931077 32.22129543]
# Number of NaNs in MINUS_DI: 14
#
# Computing Bollinger Bands (Daily)
# Daily input shape: close=(30,)
# Parameters: timeperiod=14
# Bollinger Bands output shapes: upperband=(30,), middleband=(30,), lowerband=(30,)
# Bollinger Band Width last value: 0.12364984981634557
# Bollinger Band Width sample (last 5): [0.07779316 0.08673385 0.09203957 0.10690962 0.12364985]
# Number of NaNs in Bollinger Band Width: 13
# Upper Band last value: 263.4645526203898
# Middle Band last value: 248.12428719656808
# Lower Band last value: 232.78402177274634
#
# Extracting liquidity metrics and news impact
# Last trading day: 2025-01-13, Spread: 0.15137237310409546, OBD: 1196715.75, Volume: 36400696.0, News Impact: 0
#
# Quantile window length: 130903
# Quantile window computed, shape: (130903, 10)
# Quantile window sample:
#       ticker            timestamp        open        high         low  \
# 35020   AAPL  2024-05-07 08:00:00  183.020004  183.039993       183.0
# 35021   AAPL  2024-05-07 08:01:00       183.0  183.050003       183.0
# 35022   AAPL  2024-05-07 08:02:00  182.960007  182.960007  182.960007
# 35023   AAPL  2024-05-07 08:03:00  182.960007  182.960007  182.960007
# 35024   AAPL  2024-05-07 08:04:00  182.869995  182.869995  182.699997
#
#             close  volume  estimated_bid_ask_spread  estimated_obd  \
# 35020  183.039993  3349.0                  0.039993   83739.054688
# 35021       183.0  4527.0                  0.050003   90534.476562
# 35022  182.960007   805.0                    0.0001      8050000.0
# 35023  182.960007     0.0                    0.0001       0.000001
# 35024  182.699997  2602.0                  0.169998   15306.046875
#
#        news_impact
# 35020            1
# 35021            1
# 35022            1
# 35023            1
# 35024            1
# Quantile window ticker type: <class 'str'>
# Daily aggregated quantile window shape: (172, 10)
# Daily aggregated quantile window sample:
#   ticker                 date        open        high         low       close  \
# 0   AAPL  2024-05-07 00:00:00  183.020004  184.899994  181.320007  182.394806
# 1   AAPL  2024-05-08 00:00:00  182.300003      183.75  181.449997  182.411407
# 2   AAPL  2024-05-09 00:00:00      182.75  184.779999  182.110001  184.660004
# 3   AAPL  2024-05-10 00:00:00  184.570007  185.089996  182.130005  182.580002
# 4   AAPL  2024-05-13 00:00:00  184.300003  187.100006  183.699997  186.259995
#
#        volume  estimated_bid_ask_spread  estimated_obd  news_impact
# 0  68910928.0                  0.096137     29022674.0            1
# 1  37624484.0                  0.074841      3815606.5            0
# 2  41961968.0                  0.065258     12589430.0            1
# 3  41338480.0                  0.060987      3213500.5            0
# 4  63055952.0                  0.082442    2019521.375            0
#
# Validating and cleaning daily quantile window data
# Daily quantile high dtype: double[pyarrow], NaNs: 0
# Daily quantile low dtype: double[pyarrow], NaNs: 0
# Daily quantile close dtype: double[pyarrow], NaNs: 0
#
# Computing Stochastic %K thresholds (Daily)
# Daily input shapes: high=(172,), low=(172,), close=(172,)
# Parameters: fastk_period=14
# Stochastic %K thresholds: k_low=26.79083540583846, k_high=87.96852247062395
# Stochastic %K (slowk) quantile output shape: (172,)
# Stochastic %K sample (last 5): [12.14395978  9.99046203 11.73076206 10.76616409 14.40778561]
# Number of NaNs in Stochastic %K (quantile): 17
#
# Computing ADX thresholds (Daily)
# Daily input shapes: high=(172,), low=(172,), close=(172,)
# Parameters: timeperiod=14
# ADX thresholds: adx_low=15.939592273608046, adx_high=44.06122947213901
# ADX quantile output shape: (172,)
# ADX sample (last 5): [36.80150066 34.64244986 32.94160519 32.70066158 32.95614949]
# Number of NaNs in ADX (quantile): 27
#
# Computing Bollinger Band Width threshold (Daily)
# Daily input shape: close=(172,)
# Parameters: timeperiod=14
# Bollinger Band Width threshold: 0.028450731310997984
# Bollinger Band Width quantile output shape: (172,)
# Bollinger Band Width sample (last 5): [nan nan nan nan nan]
# Number of NaNs in Bollinger Band Width (quantile): 155
#
# Computing liquidity thresholds (Daily)
# Spread thresholds: low=0.0007817240431904793, high=0.0019245573207736014
# OBD thresholds: low=1839516.625, high=3556875.099999997
# Volume threshold: high=44275026.39999999
# Sample spread (last 5): <ArrowExtensionArray>
# [0.11922303587198257, 0.14630374312400818, 0.13809674978256226,
#   0.1829075664281845, 0.15137237310409546]
# Length: 5, dtype: float[pyarrow]
# Sample OBD (last 5): <ArrowExtensionArray>
# [1235713.875, 1328780.5, 1510948.25, 2116576.0, 1196715.75]
# Length: 5, dtype: float[pyarrow]
# Sample volume (last 5): <ArrowExtensionArray>
# [30215420.0, 30383088.0, 26045970.0, 44792468.0, 36400696.0]
# Length: 5, dtype: float[pyarrow]
#
# Assigning regimes
# Regimes assigned for 2025-01-14: Volatility=Low, Trend=Range, Liquidity=Medium, News Impact=0
# Regime assigned: {'ticker': 'AAPL', 'date': Timestamp('2025-01-14 00:00:00'), 'volatility_regime': 'Low', 'trend_regime': 'Range', 'liquidity_regime': 'Medium', 'news_impact': 0}
# Regime DataFrame created, shape: (1, 6)
# Regime DataFrame dtypes:
# ticker                       object
# date                 datetime64[ns]
# volatility_regime            object
# trend_regime                 object
# liquidity_regime             object
# news_impact                   int64
# dtype: object
# Regime DataFrame ticker type: <class 'str'>
#
# Processing ticker AAPL for date 2025-01-15 00:00:00
# Predicting regime for 2025-01-15 using lookback from 2025-01-14 to earlier
# Quantile window for thresholds: 2024-05-08 to 2025-01-14
# Total trading days available up to 2025-01-14: 1182
# Lookback window: 2024-11-29 to 2025-01-14, effective lookback: 30 days
# Window shape before compute: (<dask_expr.expr.Scalar: expr=(Filter(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30))), predicate=PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30)))['timestamp'], accessor='dt', attr='date') >= 2024-11-29 & PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30)))['timestamp'], accessor='dt', attr='date') <= 2025-01-14)).size() // 10, dtype=int64>, 10)
# Quantile window shape before compute: (<dask_expr.expr.Scalar: expr=(Filter(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30))), predicate=PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30)))['timestamp'], accessor='dt', attr='date') >= 2024-05-08 & PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30)))['timestamp'], accessor='dt', attr='date') <= 2025-01-14)).size() // 10, dtype=int64>, 10)
# Unique trading days in lookback window: 30
# Lookback window computed, shape: (21234, 10)
# Lookback window sample:
#       ticker            timestamp        open        high         low  \
# 54168   AAPL  2024-11-29 09:00:00  235.369995  235.369995  235.369995
# 54169   AAPL  2024-11-29 09:01:00  235.059998  235.059998  235.059998
# 54170   AAPL  2024-11-29 09:02:00  235.089996  235.130005  235.089996
# 54171   AAPL  2024-11-29 09:03:00  235.089996  235.130005  235.089996
# 54172   AAPL  2024-11-29 09:04:00  235.089996  235.130005  235.089996
#
#             close  volume  estimated_bid_ask_spread  estimated_obd  \
# 54168  235.369995   980.0                    0.0001      9800000.0
# 54169  235.059998   383.0                    0.0001      3830000.0
# 54170  235.119995  2416.0                  0.040009   60387.101562
# 54171  235.119995     0.0                  0.040009            0.0
# 54172  235.119995     0.0                  0.040009            0.0
#
#        news_impact
# 54168            0
# 54169            0
# 54170            0
# 54171            0
# 54172            0
# Lookback window ticker type: <class 'str'>
# Daily aggregated window shape: (30, 10)
# Daily aggregated window sample:
#   ticker                 date        open        high         low       close  \
# 0   AAPL  2024-11-29 00:00:00  235.369995  237.809998  233.970001  237.330002
# 1   AAPL  2024-12-02 00:00:00  237.100006  240.789993       236.0  239.600006
# 2   AAPL  2024-12-03 00:00:00       240.0  242.759995  238.899994  242.630005
# 3   AAPL  2024-12-04 00:00:00  242.759995  244.110001      241.25  243.020004
# 4   AAPL  2024-12-05 00:00:00  242.529999  244.539993  242.100006  243.080002
#
#        volume  estimated_bid_ask_spread  estimated_obd  news_impact
# 0  24590042.0                  0.078272    117185912.0            0
# 1  32715624.0                  0.092739     1759777.75            0
# 2  28519624.0                  0.079462      5992564.5            0
# 3  30931738.0                  0.088416     2059837.75            0
# 4  29801160.0                  0.078161     12910902.0            0
#
# Validating and cleaning daily input data
# Daily high dtype: double[pyarrow], NaNs: 0
# Daily low dtype: double[pyarrow], NaNs: 0
# Daily close dtype: double[pyarrow], NaNs: 0
#
# Daily data for indicators:
#                    date        high         low       close      volume  \
# 25  2025-01-07 00:00:00  245.550003  241.350006  242.190002  30383088.0
# 26  2025-01-08 00:00:00  243.712296  240.050003  242.720001  26045970.0
# 27  2025-01-10 00:00:00       244.0       233.0  236.929993  44792468.0
# 28  2025-01-13 00:00:00  235.979996  229.720001  234.399994  36400696.0
# 29  2025-01-14 00:00:00  236.419998     232.472  233.279999  26989926.0
#
#     news_impact
# 25            0
# 26            0
# 27            1
# 28            0
# 29            0
#
# Computing Stochastic Oscillator %K (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: fastk_period=14
# Stochastic %K output shape: (30,)
# Stochastic %K (slowk) last value: 13.874961842955345
# Stochastic %K sample (last 5): [ 9.99046203 11.73076206 10.76616409 14.40778561 13.87496184]
# Number of NaNs in Stochastic %K: 17
#
# Computing ADX (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# ADX output shape: (30,)
# ADX last value: 36.07654732631064
# ADX sample (last 5): [        nan         nan 36.6542014  36.42245155 36.07654733]
# Number of NaNs in ADX: 27
#
# Computing PLUS_DI (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# PLUS_DI output shape: (30,)
# PLUS_DI last value: 15.839197975685707
# PLUS_DI sample (last 5): [22.78902887 21.42963794 17.96358021 16.12285236 15.83919798]
# Number of NaNs in PLUS_DI: 14
#
# Computing MINUS_DI (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# MINUS_DI output shape: (30,)
# MINUS_DI last value: 30.46056795842273
# MINUS_DI sample (last 5): [23.66496185 24.37075461 30.79514894 32.30117698 30.46056796]
# Number of NaNs in MINUS_DI: 14
#
# Computing Bollinger Bands (Daily)
# Daily input shape: close=(30,)
# Parameters: timeperiod=14
# Bollinger Bands output shapes: upperband=(30,), middleband=(30,), lowerband=(30,)
# Bollinger Band Width last value: 0.13498734106842825
# Bollinger Band Width sample (last 5): [0.08673385 0.09203957 0.10690962 0.12364985 0.13498734]
# Number of NaNs in Bollinger Band Width: 13
# Upper Band last value: 263.2454651685538
# Middle Band last value: 246.60142953055245
# Lower Band last value: 229.95739389255112
#
# Extracting liquidity metrics and news impact
# Last trading day: 2025-01-14, Spread: 0.13165266811847687, OBD: 1161670.625, Volume: 26989926.0, News Impact: 0
#
# Quantile window length: 130845
# Quantile window computed, shape: (130845, 10)
# Quantile window sample:
#       ticker            timestamp        open        high         low  \
# 35798   AAPL  2024-05-08 08:00:00  182.300003  182.300003  182.300003
# 35799   AAPL  2024-05-08 08:01:00  182.380005  182.380005  182.380005
# 35800   AAPL  2024-05-08 08:02:00  182.380005  182.380005  182.380005
# 35801   AAPL  2024-05-08 08:03:00  182.380005  182.380005  182.380005
# 35802   AAPL  2024-05-08 08:04:00  182.380005  182.380005  182.380005
#
#             close  volume  estimated_bid_ask_spread  estimated_obd  \
# 35798  182.300003   597.0                    0.0001      5970000.0
# 35799  182.380005   545.0                    0.0001      5450000.0
# 35800  182.380005     0.0                    0.0001       0.000001
# 35801  182.380005     0.0                    0.0001       0.000001
# 35802  182.380005     0.0                    0.0001       0.000001
#
#        news_impact
# 35798            0
# 35799            0
# 35800            0
# 35801            0
# 35802            0
# Quantile window ticker type: <class 'str'>
# Daily aggregated quantile window shape: (172, 10)
# Daily aggregated quantile window sample:
#   ticker                 date        open        high         low       close  \
# 0   AAPL  2024-05-08 00:00:00  182.300003      183.75  181.449997  182.411407
# 1   AAPL  2024-05-09 00:00:00      182.75  184.779999  182.110001  184.660004
# 2   AAPL  2024-05-10 00:00:00  184.570007  185.089996  182.130005  182.580002
# 3   AAPL  2024-05-13 00:00:00  184.300003  187.100006  183.699997  186.259995
# 4   AAPL  2024-05-14 00:00:00       186.5  188.300003  185.399994  187.550003
#
#        volume  estimated_bid_ask_spread  estimated_obd  news_impact
# 0  37624484.0                  0.074841      3815606.5            0
# 1  41961968.0                  0.065258     12589430.0            1
# 2  41338480.0                  0.060987      3213500.5            0
# 3  63055952.0                  0.082442    2019521.375            0
# 4  44522404.0                  0.077155     3189638.25            0
#
# Validating and cleaning daily quantile window data
# Daily quantile high dtype: double[pyarrow], NaNs: 0
# Daily quantile low dtype: double[pyarrow], NaNs: 0
# Daily quantile close dtype: double[pyarrow], NaNs: 0
#
# Computing Stochastic %K thresholds (Daily)
# Daily input shapes: high=(172,), low=(172,), close=(172,)
# Parameters: fastk_period=14
# Stochastic %K thresholds: k_low=26.417755333874698, k_high=87.96852247062395
# Stochastic %K (slowk) quantile output shape: (172,)
# Stochastic %K sample (last 5): [ 9.99046203 11.73076206 10.76616409 14.40778561 13.87496184]
# Number of NaNs in Stochastic %K (quantile): 17
#
# Computing ADX thresholds (Daily)
# Daily input shapes: high=(172,), low=(172,), close=(172,)
# Parameters: timeperiod=14
# ADX thresholds: adx_low=15.92579028857668, adx_high=42.31343109081144
# ADX quantile output shape: (172,)
# ADX sample (last 5): [34.64240482 32.94156221 32.70062039 32.95610995 33.06121376]
# Number of NaNs in ADX (quantile): 27
#
# Computing Bollinger Band Width threshold (Daily)
# Daily input shape: close=(172,)
# Parameters: timeperiod=14
# Bollinger Band Width threshold: 0.028450731310997984
# Bollinger Band Width quantile output shape: (172,)
# Bollinger Band Width sample (last 5): [nan nan nan nan nan]
# Number of NaNs in Bollinger Band Width (quantile): 155
#
# Computing liquidity thresholds (Daily)
# Spread thresholds: low=0.0007817240431904793, high=0.0019245573207736014
# OBD thresholds: low=1830752.5625, high=3367102.4
# Volume threshold: high=43697381.2
# Sample spread (last 5): <ArrowExtensionArray>
# [0.14630374312400818, 0.13809674978256226,  0.1829075664281845,
#  0.15137237310409546, 0.13165266811847687]
# Length: 5, dtype: float[pyarrow]
# Sample OBD (last 5): <ArrowExtensionArray>
# [1328780.5, 1510948.25, 2116576.0, 1196715.75, 1161670.625]
# Length: 5, dtype: float[pyarrow]
# Sample volume (last 5): <ArrowExtensionArray>
# [30383088.0, 26045970.0, 44792468.0, 36400696.0, 26989926.0]
# Length: 5, dtype: float[pyarrow]
#
# Assigning regimes
# Regimes assigned for 2025-01-15: Volatility=Low, Trend=Range, Liquidity=Medium, News Impact=0
# Regime assigned: {'ticker': 'AAPL', 'date': Timestamp('2025-01-15 00:00:00'), 'volatility_regime': 'Low', 'trend_regime': 'Range', 'liquidity_regime': 'Medium', 'news_impact': 0}
# Regime DataFrame created, shape: (1, 6)
# Regime DataFrame dtypes:
# ticker                       object
# date                 datetime64[ns]
# volatility_regime            object
# trend_regime                 object
# liquidity_regime             object
# news_impact                   int64
# dtype: object
# Regime DataFrame ticker type: <class 'str'>
#
# Processing ticker AAPL for date 2025-01-16 00:00:00
# Predicting regime for 2025-01-16 using lookback from 2025-01-15 to earlier
# Quantile window for thresholds: 2024-05-09 to 2025-01-15
# Total trading days available up to 2025-01-15: 1183
# Lookback window: 2024-12-02 to 2025-01-15, effective lookback: 30 days
# Window shape before compute: (<dask_expr.expr.Scalar: expr=(Filter(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30))), predicate=PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30)))['timestamp'], accessor='dt', attr='date') >= 2024-12-02 & PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30)))['timestamp'], accessor='dt', attr='date') <= 2025-01-15)).size() // 10, dtype=int64>, 10)
# Quantile window shape before compute: (<dask_expr.expr.Scalar: expr=(Filter(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30))), predicate=PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30)))['timestamp'], accessor='dt', attr='date') >= 2024-05-09 & PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30)))['timestamp'], accessor='dt', attr='date') <= 2025-01-15)).size() // 10, dtype=int64>, 10)
# Unique trading days in lookback window: 30
# Lookback window computed, shape: (21412, 10)
# Lookback window sample:
#       ticker            timestamp        open        high         low  \
# 54709   AAPL  2024-12-02 09:00:00  237.100006  237.119995  237.050003
# 54710   AAPL  2024-12-02 09:01:00  236.970001  236.970001  236.889999
# 54711   AAPL  2024-12-02 09:02:00  236.919998  236.919998  236.919998
# 54712   AAPL  2024-12-02 09:03:00  236.919998  236.919998  236.919998
# 54713   AAPL  2024-12-02 09:04:00  236.919998  236.919998  236.919998
#
#             close  volume  estimated_bid_ask_spread  estimated_obd  \
# 54709  237.050003  2270.0                  0.069992   32432.248047
# 54710  236.889999  1764.0                  0.080002   22049.496094
# 54711  236.919998   451.0                    0.0001      4510000.0
# 54712  236.919998     0.0                    0.0001       0.000001
# 54713  236.919998     0.0                    0.0001       0.000001
#
#        news_impact
# 54709            0
# 54710            0
# 54711            0
# 54712            0
# 54713            0
# Lookback window ticker type: <class 'str'>
# Daily aggregated window shape: (30, 10)
# Daily aggregated window sample:
#   ticker                 date        open        high         low       close  \
# 0   AAPL  2024-12-02 00:00:00  237.100006  240.789993       236.0  239.600006
# 1   AAPL  2024-12-03 00:00:00       240.0  242.759995  238.899994  242.630005
# 2   AAPL  2024-12-04 00:00:00  242.759995  244.110001      241.25  243.020004
# 3   AAPL  2024-12-05 00:00:00  242.529999  244.539993  242.100006  243.080002
# 4   AAPL  2024-12-06 00:00:00  242.970001  244.630005  242.080002  242.860001
#
#        volume  estimated_bid_ask_spread  estimated_obd  news_impact
# 0  32715624.0                  0.092739     1759777.75            0
# 1  28519624.0                  0.079462      5992564.5            0
# 2  30931738.0                  0.088416     2059837.75            0
# 3  29801160.0                  0.078161     12910902.0            0
# 4  29074428.0                  0.075379     41289744.0            1
#
# Validating and cleaning daily input data
# Daily high dtype: double[pyarrow], NaNs: 0
# Daily low dtype: double[pyarrow], NaNs: 0
# Daily close dtype: double[pyarrow], NaNs: 0
#
# Daily data for indicators:
#                    date        high         low       close      volume  \
# 25  2025-01-08 00:00:00  243.712296  240.050003  242.720001  26045970.0
# 26  2025-01-10 00:00:00       244.0       233.0  236.929993  44792468.0
# 27  2025-01-13 00:00:00  235.979996  229.720001  234.399994  36400696.0
# 28  2025-01-14 00:00:00  236.419998     232.472  233.279999  26989926.0
# 29  2025-01-15 00:00:00  238.960007  233.399994  237.880005  27055836.0
#
#     news_impact
# 25            0
# 26            1
# 27            0
# 28            0
# 29            1
#
# Computing Stochastic Oscillator %K (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: fastk_period=14
# Stochastic %K output shape: (30,)
# Stochastic %K (slowk) last value: 17.994284903009426
# Stochastic %K sample (last 5): [11.73076206 10.76616409 14.40778561 13.87496184 17.9942849 ]
# Number of NaNs in Stochastic %K: 17
#
# Computing ADX (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# ADX output shape: (30,)
# ADX last value: 33.12237869291214
# ADX sample (last 5): [        nan         nan 33.86372879 33.87498698 33.12237869]
# Number of NaNs in ADX: 27
#
# Computing PLUS_DI (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# PLUS_DI output shape: (30,)
# PLUS_DI last value: 17.53385043023837
# PLUS_DI sample (last 5): [20.45807321 17.12750457 15.36214831 15.12051128 17.53385043]
# Number of NaNs in PLUS_DI: 14
#
# Computing MINUS_DI (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# MINUS_DI output shape: (30,)
# MINUS_DI last value: 28.209694374973093
# MINUS_DI sample (last 5): [24.68122785 31.09711753 32.58086066 30.71404211 28.20969437]
# Number of NaNs in MINUS_DI: 14
#
# Computing Bollinger Bands (Daily)
# Daily input shape: close=(30,)
# Parameters: timeperiod=14
# Bollinger Bands output shapes: upperband=(30,), middleband=(30,), lowerband=(30,)
# Bollinger Band Width last value: 0.13416131844419613
# Bollinger Band Width sample (last 5): [0.09203957 0.10690962 0.12364985 0.13498734 0.13416132]
# Number of NaNs in Bollinger Band Width: 13
# Upper Band last value: 261.8151011260945
# Middle Band last value: 245.35643005371094
# Lower Band last value: 228.89775898132743
#
# Extracting liquidity metrics and news impact
# Last trading day: 2025-01-15, Spread: 0.11589373648166656, OBD: 2241015.75, Volume: 27055836.0, News Impact: 1
#
# Quantile window length: 130784
# Quantile window computed, shape: (130784, 10)
# Quantile window sample:
#       ticker            timestamp    open    high    low  close  volume  \
# 36578   AAPL  2024-05-09 08:00:00  182.75  182.75  182.5  182.5   694.0
# 36579   AAPL  2024-05-09 08:01:00  182.75  182.75  182.5  182.5     0.0
# 36580   AAPL  2024-05-09 08:02:00  182.75  182.75  182.5  182.5     0.0
# 36581   AAPL  2024-05-09 08:03:00  182.75  182.75  182.5  182.5     0.0
# 36582   AAPL  2024-05-09 08:04:00  182.75  182.75  182.5  182.5     0.0
#
#        estimated_bid_ask_spread  estimated_obd  news_impact
# 36578                      0.25         2776.0            1
# 36579                      0.25            0.0            1
# 36580                      0.25            0.0            1
# 36581                      0.25            0.0            1
# 36582                      0.25            0.0            1
# Quantile window ticker type: <class 'str'>
# Daily aggregated quantile window shape: (172, 10)
# Daily aggregated quantile window sample:
#   ticker                 date        open        high         low       close  \
# 0   AAPL  2024-05-09 00:00:00      182.75  184.779999  182.110001  184.660004
# 1   AAPL  2024-05-10 00:00:00  184.570007  185.089996  182.130005  182.580002
# 2   AAPL  2024-05-13 00:00:00  184.300003  187.100006  183.699997  186.259995
# 3   AAPL  2024-05-14 00:00:00       186.5  188.300003  185.399994  187.550003
# 4   AAPL  2024-05-15 00:00:00  187.429993  190.649994       187.0  189.779999
#
#        volume  estimated_bid_ask_spread  estimated_obd  news_impact
# 0  41961968.0                  0.065258     12589430.0            1
# 1  41338480.0                  0.060987      3213500.5            0
# 2  63055952.0                  0.082442    2019521.375            0
# 3  44522404.0                  0.077155     3189638.25            0
# 4  58824444.0                  0.066087      2890639.5            1
#
# Validating and cleaning daily quantile window data
# Daily quantile high dtype: double[pyarrow], NaNs: 0
# Daily quantile low dtype: double[pyarrow], NaNs: 0
# Daily quantile close dtype: double[pyarrow], NaNs: 0
#
# Computing Stochastic %K thresholds (Daily)
# Daily input shapes: high=(172,), low=(172,), close=(172,)
# Parameters: fastk_period=14
# Stochastic %K thresholds: k_low=24.922231684046896, k_high=87.96852247062395
# Stochastic %K (slowk) quantile output shape: (172,)
# Stochastic %K sample (last 5): [11.73076206 10.76616409 14.40778561 13.87496184 17.9942849 ]
# Number of NaNs in Stochastic %K (quantile): 17
#
# Computing ADX thresholds (Daily)
# Daily input shapes: high=(172,), low=(172,), close=(172,)
# Parameters: timeperiod=14
# ADX thresholds: adx_low=15.893907034541721, adx_high=41.94799733205719
# ADX quantile output shape: (172,)
# ADX sample (last 5): [32.94143676 32.70050458 32.95600299 33.06111502 32.41146846]
# Number of NaNs in ADX (quantile): 27
#
# Computing Bollinger Band Width threshold (Daily)
# Daily input shape: close=(172,)
# Parameters: timeperiod=14
# Bollinger Band Width threshold: 0.028450731310997984
# Bollinger Band Width quantile output shape: (172,)
# Bollinger Band Width sample (last 5): [nan nan nan nan nan]
# Number of NaNs in Bollinger Band Width (quantile): 155
#
# Computing liquidity thresholds (Daily)
# Spread thresholds: low=0.0007839133739471437, high=0.0019245573207736014
# OBD thresholds: low=1830752.5625, high=3349372.375
# Volume threshold: high=43697381.2
# Sample spread (last 5): <ArrowExtensionArray>
# [0.13809674978256226,  0.1829075664281845, 0.15137237310409546,
#  0.13165266811847687, 0.11589373648166656]
# Length: 5, dtype: float[pyarrow]
# Sample OBD (last 5): <ArrowExtensionArray>
# [1510948.25, 2116576.0, 1196715.75, 1161670.625, 2241015.75]
# Length: 5, dtype: float[pyarrow]
# Sample volume (last 5): <ArrowExtensionArray>
# [26045970.0, 44792468.0, 36400696.0, 26989926.0, 27055836.0]
# Length: 5, dtype: float[pyarrow]
#
# Assigning regimes
# Regimes assigned for 2025-01-16: Volatility=Low, Trend=Range, Liquidity=Medium, News Impact=1
# Regime assigned: {'ticker': 'AAPL', 'date': Timestamp('2025-01-16 00:00:00'), 'volatility_regime': 'Low', 'trend_regime': 'Range', 'liquidity_regime': 'Medium', 'news_impact': 1}
# Regime DataFrame created, shape: (1, 6)
# Regime DataFrame dtypes:
# ticker                       object
# date                 datetime64[ns]
# volatility_regime            object
# trend_regime                 object
# liquidity_regime             object
# news_impact                   int64
# dtype: object
# Regime DataFrame ticker type: <class 'str'>
#
# Processing ticker AAPL for date 2025-01-17 00:00:00
# Predicting regime for 2025-01-17 using lookback from 2025-01-16 to earlier
# Quantile window for thresholds: 2024-05-10 to 2025-01-16
# Total trading days available up to 2025-01-16: 1184
# Lookback window: 2024-12-03 to 2025-01-16, effective lookback: 30 days
# Window shape before compute: (<dask_expr.expr.Scalar: expr=(Filter(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30))), predicate=PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30)))['timestamp'], accessor='dt', attr='date') >= 2024-12-03 & PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30)))['timestamp'], accessor='dt', attr='date') <= 2025-01-16)).size() // 10, dtype=int64>, 10)
# Quantile window shape before compute: (<dask_expr.expr.Scalar: expr=(Filter(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30))), predicate=PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30)))['timestamp'], accessor='dt', attr='date') >= 2024-05-10 & PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(afc0e30)))['timestamp'], accessor='dt', attr='date') <= 2025-01-16)).size() // 10, dtype=int64>, 10)
# Unique trading days in lookback window: 30
# Lookback window computed, shape: (21412, 10)
# Lookback window sample:
#       ticker            timestamp        open        high         low  \
# 55429   AAPL  2024-12-03 09:00:00       240.0       240.0       240.0
# 55430   AAPL  2024-12-03 09:01:00       240.0       240.0       240.0
# 55431   AAPL  2024-12-03 09:02:00  239.889999  239.889999  239.880005
# 55432   AAPL  2024-12-03 09:03:00  239.880005  239.880005  239.880005
# 55433   AAPL  2024-12-03 09:04:00  239.869995  240.020004  239.820007
#
#             close   volume  estimated_bid_ask_spread  estimated_obd  \
# 55429       240.0    626.0                    0.0001      6260000.0
# 55430       240.0      0.0                    0.0001       0.000001
# 55431  239.880005    790.0                  0.009995   79043.421875
# 55432  239.880005    849.0                    0.0001      8490000.0
# 55433  239.919998  22092.0                  0.199997    110461.6875
#
#        news_impact
# 55429            0
# 55430            0
# 55431            0
# 55432            0
# 55433            0
# Lookback window ticker type: <class 'str'>
# Daily aggregated window shape: (30, 10)
# Daily aggregated window sample:
#   ticker                 date        open        high         low       close  \
# 0   AAPL  2024-12-03 00:00:00       240.0  242.759995  238.899994  242.630005
# 1   AAPL  2024-12-04 00:00:00  242.759995  244.110001      241.25  243.020004
# 2   AAPL  2024-12-05 00:00:00  242.529999  244.539993  242.100006  243.080002
# 3   AAPL  2024-12-06 00:00:00  242.970001  244.630005  242.080002  242.860001
# 4   AAPL  2024-12-09 00:00:00  242.690002  247.240005  241.570007  246.820007
#
#        volume  estimated_bid_ask_spread  estimated_obd  news_impact
# 0  28519624.0                  0.079462      5992564.5            0
# 1  30931738.0                  0.088416     2059837.75            0
# 2  29801160.0                  0.078161     12910902.0            0
# 3  29074428.0                  0.075379     41289744.0            1
# 4  31928650.0                  0.104768    1496578.125            0
#
# Validating and cleaning daily input data
# Daily high dtype: double[pyarrow], NaNs: 0
# Daily low dtype: double[pyarrow], NaNs: 0
# Daily close dtype: double[pyarrow], NaNs: 0
#
# Daily data for indicators:
#                    date        high         low       close      volume  \
# 25  2025-01-10 00:00:00       244.0       233.0  236.929993  44792468.0
# 26  2025-01-13 00:00:00  235.979996  229.720001  234.399994  36400696.0
# 27  2025-01-14 00:00:00  236.419998     232.472  233.279999  26989926.0
# 28  2025-01-15 00:00:00  238.960007  233.399994  237.880005  27055836.0
# 29  2025-01-16 00:00:00  241.410004  228.029999  228.240005  58076080.0
#
#     news_impact
# 25            1
# 26            0
# 27            0
# 28            1
# 29            0
#
# Computing Stochastic Oscillator %K (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: fastk_period=14
# Stochastic %K output shape: (30,)
# Stochastic %K (slowk) last value: 13.077616013199
# Stochastic %K sample (last 5): [10.76616409 14.40778561 13.87496184 17.9942849  13.07761601]
# Number of NaNs in Stochastic %K: 17
#
# Computing ADX (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# ADX output shape: (30,)
# ADX last value: 31.13649665383344
# ADX sample (last 5): [        nan         nan 31.2021183  30.73732768 31.13649665]
# Number of NaNs in ADX: 27
#
# Computing PLUS_DI (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# PLUS_DI output shape: (30,)
# PLUS_DI last value: 14.189529752168387
# PLUS_DI sample (last 5): [16.60309721 14.89014911 14.67536245 17.12703433 14.18952975]
# Number of NaNs in PLUS_DI: 14
#
# Computing MINUS_DI (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# MINUS_DI output shape: (30,)
# MINUS_DI last value: 30.379560995783876
# MINUS_DI sample (last 5): [31.29393704 32.75879897 30.8800859  28.36010624 30.379561  ]
# Number of NaNs in MINUS_DI: 14
#
# Computing Bollinger Bands (Daily)
# Daily input shape: close=(30,)
# Parameters: timeperiod=14
# Bollinger Bands output shapes: upperband=(30,), middleband=(30,), lowerband=(30,)
# Bollinger Band Width last value: 0.13982824880656608
# Bollinger Band Width sample (last 5): [0.10690962 0.12364985 0.13498734 0.13416132 0.13982825]
# Number of NaNs in Bollinger Band Width: 13
# Upper Band last value: 260.2206932883184
# Middle Band last value: 243.216429574149
# Lower Band last value: 226.21216585997962
#
# Extracting liquidity metrics and news impact
# Last trading day: 2025-01-16, Spread: 0.14662811160087585, OBD: 1732445.75, Volume: 58076080.0, News Impact: 0
#
# Quantile window length: 130724
# Quantile window computed, shape: (130724, 10)
# Quantile window sample:
#       ticker            timestamp        open        high         low  \
# 37358   AAPL  2024-05-10 08:00:00  184.570007  184.570007  184.570007
# 37359   AAPL  2024-05-10 08:01:00      184.75      184.75      184.75
# 37360   AAPL  2024-05-10 08:02:00  184.759995  184.759995  184.699997
# 37361   AAPL  2024-05-10 08:03:00  184.699997  184.699997  184.690002
# 37362   AAPL  2024-05-10 08:04:00  184.559998  184.729996  184.559998
#
#             close  volume  estimated_bid_ask_spread  estimated_obd  \
# 37358  184.570007   516.0                    0.0001      5160000.0
# 37359      184.75   332.0                    0.0001      3320000.0
# 37360  184.699997  1386.0                  0.059998   23100.939453
# 37361  184.690002   765.0                  0.009995   76542.046875
# 37362  184.729996   717.0                  0.169998    4217.692383
#
#        news_impact
# 37358            0
# 37359            0
# 37360            0
# ...
# Quantile window shape before compute: (<dask_expr.expr.Scalar: expr=(Filter(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(18cb905))), predicate=PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(18cb905)))['timestamp'], accessor='dt', attr='date') >= 2022-11-01 & PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(18cb905)))['timestamp'], accessor='dt', attr='date') <= 2023-07-10)).size() // 10, dtype=int64>, 10)
# Unique trading days in lookback window: 30
# Lookback window computed, shape: (16384, 10)
# Lookback window sample:
#       ticker            timestamp        open        high         low  \
# 14397    ADI  2023-05-25 08:00:00  172.100006  172.100006  172.100006
# 14398    ADI  2023-05-25 08:01:00  172.100006  172.100006  172.100006
# 14399    ADI  2023-05-25 08:02:00  172.100006  172.100006  172.100006
# 14400    ADI  2023-05-25 08:03:00  172.100006  172.100006  172.100006
# 14401    ADI  2023-05-25 08:04:00  172.100006  172.100006  172.100006
#
#             close  volume  estimated_bid_ask_spread  estimated_obd  \
# 14397  172.100006   135.0                    0.0001      1350000.0
# 14398  172.100006     0.0                    0.0001       0.000001
# 14399  172.100006     0.0                    0.0001       0.000001
# 14400  172.100006     0.0                    0.0001       0.000001
# 14401  172.100006     0.0                    0.0001       0.000001
#
#        news_impact
# 14397            1
# 14398            1
# 14399            1
# 14400            1
# 14401            1
# Lookback window ticker type: <class 'str'>
# Daily aggregated window shape: (30, 10)
# Daily aggregated window sample:
#   ticker                 date        open        high         low       close  \
# 0    ADI  2023-05-25 00:00:00  172.100006  173.940002  161.925003       172.0
# 1    ADI  2023-05-26 00:00:00  172.639999  177.735001  171.199997  176.529999
# 2    ADI  2023-05-30 00:00:00       178.0  179.899994  174.809998  177.429993
# 3    ADI  2023-05-31 00:00:00  175.610001  179.994995  174.960007  177.690002
# 4    ADI  2023-06-01 00:00:00  177.759995  182.195007  176.699997  180.410004
#
#       volume  estimated_bid_ask_spread  estimated_obd  news_impact
# 0  8640095.0                  0.172432      5011385.5            1
# 1  5183755.0                  0.150019     4120538.75            0
# 2  4116652.5                  0.228345      3914155.0            0
# 3  4305390.5                  0.122799      4828546.0            0
# 4  3331992.0                  0.129071      2566560.0            0
#
# Validating and cleaning daily input data
# Daily high dtype: double[pyarrow], NaNs: 0
# Daily low dtype: double[pyarrow], NaNs: 0
# Daily close dtype: double[pyarrow], NaNs: 0
#
# Daily data for indicators:
#                    date        high         low       close     volume  \
# 25  2023-07-03 00:00:00  196.549896  192.270004  194.330002  1429624.5
# 26  2023-07-05 00:00:00  194.330002  189.869995       190.0  2116868.0
# 27  2023-07-06 00:00:00  187.960007  184.571198  186.199997  4211557.0
# 28  2023-07-07 00:00:00  188.654999  185.179993  185.309998  2321383.0
# 29  2023-07-10 00:00:00  191.089996  185.770004  191.050003  8094763.0
#
#     news_impact
# 25            0
# 26            0
# 27            0
# 28            1
# 29            0
#
# Computing Stochastic Oscillator %K (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: fastk_period=14
# Stochastic %K output shape: (30,)
# Stochastic %K (slowk) last value: 32.20747373127911
# Stochastic %K sample (last 5): [81.32217242 76.54200102 52.1525707  29.57981884 32.20747373]
# Number of NaNs in Stochastic %K: 17
#
# Computing ADX (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# ADX output shape: (30,)
# ADX last value: 37.029853969273496
# ADX sample (last 5): [        nan         nan 39.72868948 38.07644217 37.02985397]
# Number of NaNs in ADX: 27
#
# Computing PLUS_DI (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# PLUS_DI output shape: (30,)
# PLUS_DI last value: 28.35861552357835
# PLUS_DI sample (last 5): [32.17945616 29.92836975 27.41447754 27.00864206 28.35861552]
# Number of NaNs in PLUS_DI: 14
#
# Computing MINUS_DI (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# MINUS_DI output shape: (30,)
# MINUS_DI last value: 17.59446958811994
# MINUS_DI sample (last 5): [10.31945909 13.36192755 20.43811303 19.3194615  17.59446959]
# Number of NaNs in MINUS_DI: 14
#
# Computing Bollinger Bands (Daily)
# Daily input shape: close=(30,)
# Parameters: timeperiod=14
# Bollinger Bands output shapes: upperband=(30,), middleband=(30,), lowerband=(30,)
# Bollinger Band Width last value: 0.06614880746317135
# Bollinger Band Width sample (last 5): [0.06358093 0.06081136 0.06180631 0.06518447 0.06614881]
# Number of NaNs in Bollinger Band Width: 13
# Upper Band last value: 195.2665577907871
# Middle Band last value: 189.01499938964844
# Lower Band last value: 182.76344098850979
#
# Extracting liquidity metrics and news impact
# Last trading day: 2023-07-10, Spread: 0.057464975863695145, OBD: 77025776.0, Volume: 8094763.0, News Impact: 0
#
# Quantile window length: 83953
# Quantile window computed, shape: (83953, 10)
# Quantile window sample:
#      ticker            timestamp        open        high         low  \
# 7285    ADI  2022-11-01 11:00:00  144.139999  144.139999  144.139999
# 7286    ADI  2022-11-01 11:01:00  144.139999  144.139999  144.139999
# 7287    ADI  2022-11-01 11:02:00  144.139999  144.139999  144.139999
# 7288    ADI  2022-11-01 11:03:00  144.139999  144.139999  144.139999
# 7289    ADI  2022-11-01 11:04:00  144.139999  144.139999  144.139999
#
#            close      volume  estimated_bid_ask_spread  estimated_obd  \
# 7285  144.139999       214.0                    0.0001      2140000.0
# 7286  144.139999  218.563751                    0.0001      2185637.5
# 7287  144.139999  223.127518                    0.0001     2231275.25
# 7288  144.139999  227.691269                    0.0001     2276912.75
# 7289  144.139999  232.255035                    0.0001     2322550.25
#
#       news_impact
# 7285            0
# 7286            0
# 7287            0
# 7288            0
# 7289            0
# Quantile window ticker type: <class 'str'>
# Daily aggregated quantile window shape: (171, 10)
# Daily aggregated quantile window sample:
#   ticker                 date        open        high         low       close  \
# 0    ADI  2022-11-01 00:00:00  144.139999  145.910004  143.320007  144.339996
# 1    ADI  2022-11-02 00:00:00  144.630005  147.809998  141.020004  141.190002
# 2    ADI  2022-11-03 00:00:00  140.419998  141.009995  137.789993  138.020004
# 3    ADI  2022-11-04 00:00:00  138.210007  145.399994  138.210007  144.289993
# 4    ADI  2022-11-07 00:00:00  145.009995  149.190002  143.880005  148.988998
#
#       volume  estimated_bid_ask_spread  estimated_obd  news_impact
# 0  2047973.0                  0.088387      2369294.5            0
# 1  2518312.5                   0.15697    662707.4375            1
# 2  3189555.0                  0.115513      1816232.5            1
# 3  4135452.5                  0.168613     21383516.0            1
# 4  2690885.0                  0.096169     1352571.75            0
#
# Validating and cleaning daily quantile window data
# Daily quantile high dtype: double[pyarrow], NaNs: 0
# Daily quantile low dtype: double[pyarrow], NaNs: 0
# Daily quantile close dtype: double[pyarrow], NaNs: 0
#
# Computing Stochastic %K thresholds (Daily)
# Daily input shapes: high=(171,), low=(171,), close=(171,)
# Parameters: fastk_period=14
# Stochastic %K thresholds: k_low=32.16127499198206, k_high=77.6016890886487
# Stochastic %K (slowk) quantile output shape: (171,)
# Stochastic %K sample (last 5): [81.32217242 76.54200102 52.1525707  29.57981884 32.20747373]
# Number of NaNs in Stochastic %K (quantile): 17
#
# Computing ADX thresholds (Daily)
# Daily input shapes: high=(171,), low=(171,), close=(171,)
# Parameters: timeperiod=14
# ADX thresholds: adx_low=15.892090070135298, adx_high=24.444672235943237
# ADX quantile output shape: (171,)
# ADX sample (last 5): [16.01749411 16.10849549 15.02997586 14.03989929 13.65169506]
# Number of NaNs in ADX (quantile): 27
#
# Computing Bollinger Band Width threshold (Daily)
# Daily input shape: close=(171,)
# Parameters: timeperiod=14
# Bollinger Band Width threshold: 0.06399905043059821
# Bollinger Band Width quantile output shape: (171,)
# Bollinger Band Width sample (last 5): [nan nan nan nan nan]
# Number of NaNs in Bollinger Band Width (quantile): 154
#
# Computing liquidity thresholds (Daily)
# Spread thresholds: low=0.0008577629923820496, high=0.001909463182091713
# OBD thresholds: low=599039.3125, high=2535283.75
# Volume threshold: high=3105313.9999999995
# Sample spread (last 5): <ArrowExtensionArray>
# [  0.1055176630616188,  0.10422516614198685,   0.1054205670952797,
#   0.11638814955949783, 0.057464975863695145]
# Length: 5, dtype: float[pyarrow]
# Sample OBD (last 5): <ArrowExtensionArray>
# [6186710.0, 1053934.25, 24520460.0, 2343244.0, 77025776.0]
# Length: 5, dtype: float[pyarrow]
# Sample volume (last 5): <ArrowExtensionArray>
# [1429624.5, 2116868.0, 4211557.0, 2321383.0, 8094763.0]
# Length: 5, dtype: float[pyarrow]
#
# Assigning regimes
# Regimes assigned for 2023-07-11: Volatility=Medium, Trend=Uptrend, Liquidity=High, News Impact=0
# Regime assigned: {'ticker': 'ADI', 'date': Timestamp('2023-07-11 00:00:00'), 'volatility_regime': 'Medium', 'trend_regime': 'Uptrend', 'liquidity_regime': 'High', 'news_impact': 0}
# Regime DataFrame created, shape: (1, 6)
# Regime DataFrame dtypes:
# ticker                       object
# date                 datetime64[ns]
# volatility_regime            object
# trend_regime                 object
# liquidity_regime             object
# news_impact                   int64
# dtype: object
# Regime DataFrame ticker type: <class 'str'>
#
# Processing ticker ADI for date 2023-07-12 00:00:00
# Predicting regime for 2023-07-12 using lookback from 2023-07-11 to earlier
# Quantile window for thresholds: 2022-11-02 to 2023-07-11
# Total trading days available up to 2023-07-11: 802
# Lookback window: 2023-05-26 to 2023-07-11, effective lookback: 30 days
# Window shape before compute: (<dask_expr.expr.Scalar: expr=(Filter(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(18cb905))), predicate=PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(18cb905)))['timestamp'], accessor='dt', attr='date') >= 2023-05-26 & PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(18cb905)))['timestamp'], accessor='dt', attr='date') <= 2023-07-11)).size() // 10, dtype=int64>, 10)
# Quantile window shape before compute: (<dask_expr.expr.Scalar: expr=(Filter(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(18cb905))), predicate=PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(18cb905)))['timestamp'], accessor='dt', attr='date') >= 2022-11-02 & PropertyMap(frame=Assign(frame=Assign(frame=ReadParquetFSSpec(18cb905)))['timestamp'], accessor='dt', attr='date') <= 2023-07-11)).size() // 10, dtype=int64>, 10)
# Unique trading days in lookback window: 30
# Lookback window computed, shape: (16022, 10)
# Lookback window sample:
#       ticker            timestamp        open        high         low  \
# 15165    ADI  2023-05-26 11:40:00  172.639999  172.639999  172.639999
# 15166    ADI  2023-05-26 11:41:00  172.639999  172.639999  172.639999
# 15167    ADI  2023-05-26 11:42:00  172.639999  172.639999  172.639999
# 15168    ADI  2023-05-26 11:43:00  172.639999  172.639999  172.639999
# 15169    ADI  2023-05-26 11:44:00  172.639999  172.639999  172.639999
#
#             close      volume  estimated_bid_ask_spread  estimated_obd  \
# 15165  172.639999       539.0                    0.0001      5390000.0
# 15166  172.639999   534.39563                    0.0001      5343956.5
# 15167  172.639999  529.791199                    0.0001      5297912.0
# 15168  172.639999  525.186829                    0.0001      5251868.5
# 15169  172.639999  520.582397                    0.0001      5205824.0
#
#        news_impact
# 15165            0
# 15166            0
# 15167            0
# 15168            0
# 15169            0
# Lookback window ticker type: <class 'str'>
# Daily aggregated window shape: (30, 10)
# Daily aggregated window sample:
#   ticker                 date        open        high         low       close  \
# 0    ADI  2023-05-26 00:00:00  172.639999  177.735001  171.199997  176.529999
# 1    ADI  2023-05-30 00:00:00       178.0  179.899994  174.809998  177.429993
# 2    ADI  2023-05-31 00:00:00  175.610001  179.994995  174.960007  177.690002
# 3    ADI  2023-06-01 00:00:00  177.759995  182.195007  176.699997  180.410004
# 4    ADI  2023-06-02 00:00:00       181.0       182.0  178.919998  179.800003
#
#       volume  estimated_bid_ask_spread  estimated_obd  news_impact
# 0  5183755.0                  0.150019     4120538.75            0
# 1  4116652.5                  0.228345      3914155.0            0
# 2  4305390.5                  0.122799      4828546.0            0
# 3  3331992.0                  0.129071      2566560.0            0
# 4  3127967.0                  0.118815     3542016.75            1
#
# Validating and cleaning daily input data
# Daily high dtype: double[pyarrow], NaNs: 0
# Daily low dtype: double[pyarrow], NaNs: 0
# Daily close dtype: double[pyarrow], NaNs: 0
#
# Daily data for indicators:
#                    date        high         low       close     volume  \
# 25  2023-07-05 00:00:00  194.330002  189.869995       190.0  2116868.0
# 26  2023-07-06 00:00:00  187.960007  184.571198  186.199997  4211557.0
# 27  2023-07-07 00:00:00  188.654999  185.179993  185.309998  2321383.0
# 28  2023-07-10 00:00:00  191.089996  185.770004  191.050003  8094763.0
# 29  2023-07-11 00:00:00  192.070007  187.598099  190.949997  1736599.0
#
#     news_impact
# 25            0
# 26            0
# 27            1
# 28            0
# 29            0
#
# Computing Stochastic Oscillator %K (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: fastk_period=14
# Stochastic %K output shape: (30,)
# Stochastic %K (slowk) last value: 44.0944494021878
# Stochastic %K sample (last 5): [76.54200102 52.1525707  29.57981884 32.20747373 44.0944494 ]
# Number of NaNs in Stochastic %K: 17
#
# Computing ADX (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# ADX output shape: (30,)
# ADX last value: 30.960284372974268
# ADX sample (last 5): [        nan         nan 32.31546462 31.51071241 30.96028437]
# Number of NaNs in ADX: 27
#
# Computing PLUS_DI (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# PLUS_DI output shape: (30,)
# PLUS_DI last value: 27.149989502437627
# PLUS_DI sample (last 5): [28.91064573 26.45530633 26.0982677  27.54317061 27.1499895 ]
# Number of NaNs in PLUS_DI: 14
#
# Computing MINUS_DI (Daily)
# Daily input shapes: high=(30,), low=(30,), close=(30,)
# Parameters: timeperiod=14
# MINUS_DI output shape: (30,)
# MINUS_DI last value: 16.709387613990838
# MINUS_DI sample (last 5): [13.78086282 20.89994915 19.74403428 17.96432754 16.70938761]
# Number of NaNs in MINUS_DI: 14
#
# Computing Bollinger Bands (Daily)
# Daily input shape: close=(30,)
# Parameters: timeperiod=14
# Bollinger Bands output shapes: upperband=(30,), middleband=(30,), lowerband=(30,)
# Bollinger Band Width last value: 0.06656623293795816
# Bollinger Band Width sample (last 5): [0.06081136 0.06180631 0.06518447 0.06614881 0.06656623]
# Number of NaNs in Bollinger Band Width: 13
# Upper Band last value: 195.52521135137846
# Middle Band last value: 189.22714233398438
# Lower Band last value: 182.9290733165903
#
# Extracting liquidity metrics and news impact
# Last trading day: 2023-07-11, Spread: 0.11804880201816559, OBD: 2748589.75, Volume: 1736599.0, News Impact: 0
#
# Quantile window length: 83777
# Buffered data was truncated after reaching the output size limit.

# %% [markdown]
# ### Regime distributions and summaries

# %%
def validate_regime_distribution(regimes_df, min_pct=0.05):
    if regimes_df.empty:
        logging.warning("Regime DataFrame is empty")
        return pd.DataFrame()

    regime_counts = regimes_df.groupby('date').agg({
        'volatility_regime': lambda x: x.value_counts().to_dict(),
        'trend_regime': lambda x: x.value_counts().to_dict(),
        'liquidity_regime': lambda x: x.value_counts().to_dict(),
        'news_impact': lambda x: x.value_counts().to_dict()
    }).reset_index()

    for regime_type in ['volatility_regime', 'trend_regime', 'liquidity_regime', 'news_impact']:
        for _, row in regime_counts.iterrows():
            date = row['date']
            counts = row[regime_type]
            total = sum(counts.values())
            if total == 0:
                logging.warning(f"No {regime_type} assignments for {date}")
                continue
            for regime, count in counts.items():
                pct = count / total
                if regime == 'undefined' and regime_type != 'news_impact':
                    logging.info(f"{regime_type} has {count} undefined assignments on {date} ({pct:.2%})")
                elif pd.isna(regime):
                    logging.warning(f"{regime_type} has {count} NaN assignments on {date} ({pct:.2%})")
                elif pct < min_pct and regime_type != 'news_impact':
                    logging.warning(f"Low representation of {regime_type}={regime} on {date}: {pct:.2%} (<{min_pct:.2%})")

    return regime_counts

def plot_regime_distribution(regime_counts):
    if regime_counts.empty:
        logging.warning("No regime counts to plot")
        return

    os.makedirs(PLOT_DIR, exist_ok=True)
    for regime_type in ['volatility_regime', 'trend_regime', 'liquidity_regime', 'news_impact']:
        counts = regime_counts[regime_type].apply(
            lambda x: pd.Series(x) / pd.Series(x).sum()
        ).fillna(0)
        plt.figure(figsize=(12, 8))
        counts.plot(kind='area', stacked=True, title=f'{regime_type} Distribution')
        plt.xlabel('Date')
        plt.ylabel('Proportion')
        plt.legend(title=regime_type)
        plt.savefig(os.path.join(PLOT_DIR, f'{regime_type}_distribution.png'))
        plt.close()

def print_regime_distribution_summary(regimes_df):
    regimes_df = regimes_df.copy()
    for col in ['volatility_regime', 'trend_regime', 'liquidity_regime']:
        regimes_df[col] = regimes_df[col].fillna('NaN')

    for regime_type in ['volatility_regime', 'trend_regime', 'liquidity_regime', 'news_impact']:
        print(f"\n{regime_type.replace('_regime', '').capitalize()}:")
        counts = regimes_df[regime_type].value_counts(normalize=True) * 100
        for regime, pct in counts.items():
            print(f"  {regime}: {pct:.2f}%")

    regimes_df['year'] = regimes_df['date'].dt.year
    for regime_type in ['volatility_regime', 'trend_regime', 'liquidity_regime', 'news_impact']:
        print(f"\n{regime_type.replace('_regime', '').capitalize()}:")
        yearly_counts = regimes_df.groupby('year')[regime_type].value_counts(normalize=True).unstack().fillna(0) * 100
        print(yearly_counts.round(2))

    for regime_type in ['volatility_regime', 'trend_regime', 'liquidity_regime', 'news_impact']:
        print(f"\n{regime_type.replace('_regime', '').capitalize()}:")
        ticker_counts = regimes_df.groupby('ticker')[regime_type].value_counts(normalize=True).unstack().fillna(0) * 100
        for regime in ticker_counts.columns:
            max_ticker = ticker_counts[regime].idxmax()
            min_ticker = ticker_counts[regime].idxmin()
            print(f"  {regime}:")
            print(f"    Highest: {max_ticker} ({ticker_counts.loc[max_ticker, regime]:.2f}%)")
            print(f"    Lowest: {min_ticker} ({ticker_counts.loc[min_ticker, regime]:.2f}%)")

    total_days = len(regimes_df)
    undefined_counts = regimes_df[regimes_df[['volatility_regime', 'trend_regime', 'liquidity_regime']].eq('undefined').any(axis=1)]
    nan_counts = regimes_df[regimes_df[['volatility_regime', 'trend_regime', 'liquidity_regime']].eq('NaN').any(axis=1)]
    undefined_days = len(undefined_counts)
    nan_days = len(nan_counts)
    print(f"Total ticker-days with at least one undefined regime: {undefined_days} ({undefined_days/total_days*100:.2f}%)")
    print(f"Total ticker-days with at least one NaN regime: {nan_days} ({nan_days/total_days*100:.2f}%)")
    for regime_type in ['volatility_regime', 'trend_regime', 'liquidity_regime', 'news_impact']:
        undef_pct = (regimes_df[regime_type] == 'undefined').mean() * 100 if regime_type != 'news_impact' else 0
        nan_pct = (regimes_df[regime_type].isna()).mean() * 100
        print(f"  {regime_type.replace('_regime', '').capitalize()}:")
        print(f"    Undefined: {undef_pct:.2f}%")
        print(f"    NaN: {nan_pct:.2f}%")

    for regime_type in ['volatility_regime', 'trend_regime', 'liquidity_regime', 'news_impact']:
        print(f"\n{regime_type.replace('_regime', '').capitalize()}:")
        undef_ticker_counts = regimes_df[regimes_df[regime_type] == 'undefined'].groupby('ticker').size() if regime_type != 'news_impact' else pd.Series()
        nan_ticker_counts = regimes_df[regimes_df[regime_type].isna()].groupby('ticker').size()
        if not undef_ticker_counts.empty:
            top_undef_ticker = undef_ticker_counts.idxmax()
            print(f"  Undefined - Highest: {top_undef_ticker} ({undef_ticker_counts.max()} days)")
        else:
            print("  Undefined - None")
        if not nan_ticker_counts.empty:
            top_nan_ticker = nan_ticker_counts.idxmax()
            print(f"  NaN - Highest: {top_nan_ticker} ({nan_ticker_counts.max()} days)")
        else:
            print("  NaN - None")

# %% [markdown]
# ### Main

# %%
def main():
    all_regimes = []

    for ticker in tickers:  
        logging.info(f"Processing ticker: {ticker}")
        regimes = process_ticker(ticker)
        if regimes is not None:
            all_regimes.append(regimes)
            logging.info(f"Successfully processed {ticker}")
        else:
            logging.warning(f"Failed to process {ticker}")

    if not all_regimes:
        logging.error("No regimes computed for any ticker")
        return

    regimes_df = pd.concat(all_regimes, ignore_index=True)

    assigned_tickers = set(regimes_df['ticker'].unique())
    missing_tickers = set(tickers) - assigned_tickers
    if missing_tickers:
        logging.warning(f"Missing regime assignments for tickers: {missing_tickers}")

    regime_counts = validate_regime_distribution(regimes_df)
    if not regime_counts.empty:
        regime_counts.to_csv(LOG_CSV, index=False)
        logging.info(f"Saved regime counts to {LOG_CSV}")
    else:
        logging.warning("No regime counts to save")

    plot_regime_distribution(regime_counts)
    print_regime_distribution_summary(regimes_df)

    # Saving aggregated regimes
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    regimes_df.to_csv(os.path.join(OUTPUT_DIR, 'all_regimes.csv'), index=False)
    logging.info(f"Saving aggregated regimes to {OUTPUT_DIR}/all_regimes.csv")
    logging.info("Main executed successfully")

if __name__ == "__main__":
    print("Starting script execution")
    main()
    print("Script execution completed")

# %%
# Closing the client and cluster
client.close()
cluster.close()
# Out:
# INFO:distributed.scheduler:Remove client Client-c2ef4c20-2860-11f0-bd9c-0242c0a80a0a
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:36560; closing.
# INFO:distributed.scheduler:Remove client Client-c2ef4c20-2860-11f0-bd9c-0242c0a80a0a
# INFO:distributed.scheduler:Close client connection: Client-c2ef4c20-2860-11f0-bd9c-0242c0a80a0a
# INFO:distributed.scheduler:Retire worker addresses (stimulus_id='retire-workers-1746306469.1812365') (0, 1, 2, 3, 4, 5, 6, 7)
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:42337'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:45425'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:33207'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:33399'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:43687'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:42633'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:45823'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.nanny:Closing Nanny at 'tcp://127.0.0.1:37137'. Reason: nanny-close
# INFO:distributed.nanny:Nanny asking worker to close. Reason: nanny-close
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:36484; closing.
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:36482; closing.
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:36490; closing.
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:36518; closing.
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:36502; closing.
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:36522; closing.
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:36538; closing.
# INFO:distributed.scheduler:Remove worker addr: tcp://127.0.0.1:33445 name: 0 (stimulus_id='handle-worker-cleanup-1746306469.2212064')
# INFO:distributed.scheduler:Remove worker addr: tcp://127.0.0.1:39453 name: 1 (stimulus_id='handle-worker-cleanup-1746306469.2231328')
# INFO:distributed.scheduler:Remove worker addr: tcp://127.0.0.1:43101 name: 2 (stimulus_id='handle-worker-cleanup-1746306469.2249951')
# INFO:distributed.scheduler:Remove worker addr: tcp://127.0.0.1:35171 name: 3 (stimulus_id='handle-worker-cleanup-1746306469.2267592')
# INFO:distributed.scheduler:Remove worker addr: tcp://127.0.0.1:39749 name: 4 (stimulus_id='handle-worker-cleanup-1746306469.228493')
# INFO:distributed.scheduler:Remove worker addr: tcp://127.0.0.1:37735 name: 5 (stimulus_id='handle-worker-cleanup-1746306469.2302275')
# INFO:distributed.scheduler:Remove worker addr: tcp://127.0.0.1:46489 name: 6 (stimulus_id='handle-worker-cleanup-1746306469.231997')
# INFO:distributed.core:Received 'close-stream' from tcp://127.0.0.1:36554; closing.
# INFO:distributed.scheduler:Remove worker addr: tcp://127.0.0.1:35809 name: 7 (stimulus_id='handle-worker-cleanup-1746306469.2468798')
# INFO:distributed.scheduler:Lost all workers
# INFO:distributed.nanny:Nanny at 'tcp://127.0.0.1:33399' closed.
# INFO:distributed.nanny:Nanny at 'tcp://127.0.0.1:45425' closed.
# INFO:distributed.nanny:Nanny at 'tcp://127.0.0.1:42337' closed.
# INFO:distributed.nanny:Nanny at 'tcp://127.0.0.1:43687' closed.
# INFO:distributed.nanny:Nanny at 'tcp://127.0.0.1:37137' closed.
# INFO:distributed.nanny:Nanny at 'tcp://127.0.0.1:45823' closed.
# INFO:distributed.nanny:Nanny at 'tcp://127.0.0.1:33207' closed.
# INFO:distributed.nanny:Nanny at 'tcp://127.0.0.1:42633' closed.
# INFO:distributed.scheduler:Closing scheduler. Reason: unknown
# INFO:distributed.scheduler:Scheduler closing all comms
